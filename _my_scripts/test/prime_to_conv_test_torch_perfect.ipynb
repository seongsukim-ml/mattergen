# %%
import sys
import os
from pathlib import Path
sys.path.append(Path.cwd().parent.as_posix())
from util import *
from visualizer import visualizer
vis = visualizer()

from mattergen.self_guidance.wyckoff_dataset_prim import *
from mattergen.self_guidance.wyckoff_sampler_prim_new import *
from mattergen.common.data.collate import collate

# %%
# def get_latttice_permutations(device="cpu"):
#     lat_perm = np.zeros((231, 3, 3, 3, 3, 3))
#     lat_perm[:, :, :, :, 0, 0] = 1
#     lat_perm[:, :, :, :, 1, 1] = 1
#     lat_perm[:, :, :, :, 2, 2] = 1
#     # Ex) 1, 0, 2 implies lat(1) > lat(0) > lat(2)
#     possible_perms = [[0, 1, 2], [0, 2, 1], [1, 0, 2], [1, 2, 0], [2, 0, 1], [2, 1, 0]]

#     perm_for_A1 = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
#     perm_for_A2 = np.eye(3).reshape(1, 3, 3).repeat(231, axis=0)
#     lat_perm[:, 0, 1, 2] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
#     lat_perm[:, 0, 2, 1] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
#     lat_perm[:, 1, 0, 2] = np.array([[0, 0, 1], [1, 0, 0], [0, 1, 0]])
#     lat_perm[:, 1, 2, 0] = np.array([[1, 0, 0], [0, 0, 1], [0, 1, 0]])
#     lat_perm[:, 2, 0, 1] = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
#     lat_perm[:, 2, 1, 0] = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])

#     # orthorhombic with A:
#     for i in [38, 39, 40, 41]:
#         for p in possible_perms:
#             lat_perm[i, p[0], p[1], p[2]] = perm_for_A1 @ lat_perm[0, p[0], p[1], p[2]]
#         # perm_for_A2[i] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
#     lat_perm = torch.tensor(lat_perm, dtype=torch.float32)
#     perm_for_A1 = torch.tensor(perm_for_A1, dtype=torch.float32)
#     perm_for_A2 = torch.tensor(perm_for_A2, dtype=torch.float32)
#     return lat_perm.to(device), perm_for_A1.to(device), perm_for_A2.to(device)

# def _project_to_space_group(batch,pos=None,cell=None):
#     cf = CrystalFamily()
#     cf.set_device(batch.pos.device)
#     lat_perm, _, perm_for_A2 = get_latttice_permutations(device=batch.pos.device)
#     if pos is not None:
#         batch = batch.replace(pos=pos)
#     else:
#         batch = batch.replace(pos=torch.rand_like(batch.pos))
#     if cell is not None:
#         batch = batch.replace(cell=cell)
#     else:
#         batch = batch.replace(cell=torch.tensor(initialize_random_lattice().matrix).unsqueeze(0).float())

#     wyckoff_batch = batch.wyckoff_bat.clone()
#     idx, cum = 0, 0
#     for len, num_atom in zip(batch.wyckoff_bat_len, batch.num_atoms):
#         wyckoff_batch[idx : idx + len] = wyckoff_batch[idx : idx + len] + cum
#         idx += len
#         cum += num_atom

#     # project latice
#     conv_lat = torch.bmm(batch.prim_to_conv, batch.cell)
#     conv_lat_vec = cf.m2v(cf.de_so3(conv_lat))
#     conv_lat_vec_proj = cf.proj_k_to_spacegroup(conv_lat_vec, batch.space_groups)
#     conv_lat_proj = cf.v2m(conv_lat_vec_proj)
#     print("conv_lat_proj") # The same
#     print(conv_lat_proj)

#     rank = torch.argsort(-torch.norm(conv_lat_proj, dim=-1), dim=-1)
#     idx = torch.cat([batch.space_groups.unsqueeze(-1), rank], dim=-1)
#     perm = lat_perm[idx[:, 0], idx[:, 1], idx[:, 2], idx[:, 3]]
#     perm_A = perm_for_A2[batch.space_groups]
#     # perm = perm_for_A2[0].unsqueeze(0).repeat(batch.space_groups.shape[0], 1, 1)
    

#     perm_conv_lat_proj = torch.bmm(torch.bmm(perm, conv_lat_proj), perm.transpose(-1, -2))
#     perm_conv_lat_proj = torch.bmm(
#         torch.bmm(perm_A, perm_conv_lat_proj), perm_A.transpose(-1, -2)
#     )
#     # perm_conv_lat_proj = conv_lat_proj

#     prim_lat_proj = torch.bmm(torch.bmm(torch.bmm(perm_A,batch.conv_to_prim),perm_A.transpose(-1,-2)), perm_conv_lat_proj)
#     prim_lat_proj = torch.bmm(batch.conv_to_prim, perm_conv_lat_proj)
#     print(perm)
#     print(perm.transpose(-1,-2))
#     print(perm_A)
#     print(perm_conv_lat_proj)

#     batch_cell = torch.bmm(torch.bmm(perm, batch.cell), perm.transpose(-1, -2)) 
#     pos_cart = torch.einsum("bi,bij->bj", batch.pos, batch_cell[batch.batch])
#     print("pos_cart")
#     print(pos_cart)
#     pos_frac_conv = torch.einsum(
#         "bi,bij->bj", pos_cart, torch.inverse(perm_conv_lat_proj)[batch.batch]
#     )
#     pos_frac_conv = pos_frac_conv % 1.0
#     print("pos_frac_conv")
#     print(pos_frac_conv)
#     pos_tran = torch.cat(
#         [
#             pos_frac_conv[wyckoff_batch],
#             torch.ones(pos_frac_conv[wyckoff_batch].shape[0], 1, device=batch.pos.device),
#         ],
#         dim=1,
#     )

#     pos_frac_proj = (
#         torch.einsum("bij,bj->bi", batch.wyckoff_ops, pos_tran).squeeze(-1)[:, :3] % 1.0
#     )
#     no_perm_pos_frac_proj = pos_frac_proj.clone()
#     pos_frac_proj = torch.einsum("bij,bj->bi", perm[batch.batch[wyckoff_batch]], pos_frac_proj)
#     pos_cart_proj = torch.einsum(
#         "bi,bij->bj", pos_frac_proj, perm_conv_lat_proj[batch.batch[wyckoff_batch]]
#     )
#     # print("pos_cart_proj")
#     # print(pos_cart_proj)

#     prim_lat_inv = torch.inverse(prim_lat_proj)
#     pos_prim_frac_proj_all = torch.einsum(
#         "bi,bij->bj", pos_cart_proj, prim_lat_inv[batch.batch[wyckoff_batch]]
#     )
#     # print("pos_prim_frac_proj_all")
#     # print(pos_prim_frac_proj_all)

#     ## Get prim idx
#     for i in range(10):
#         random_pos_frac_conv = torch.rand_like(pos_frac_conv).to(pos_frac_conv.device)
#         random_pos_tran = torch.cat(
#             [
#                 random_pos_frac_conv[wyckoff_batch],
#                 torch.ones(
#                     random_pos_frac_conv[wyckoff_batch].shape[0],
#                     1,
#                     device=pos_frac_conv.device,
#                 ),
#             ],
#             dim=1,
#         )
#         random_pos_frac_proj = (
#             torch.einsum("bij,bj->bi", batch.wyckoff_ops, random_pos_tran).squeeze(-1)[
#                 :, :3
#             ]
#             % 1.0
#         ) % 1.0
#         random_pos_frac_proj = torch.einsum(
#             "bij,bj->bi", perm[batch.batch[wyckoff_batch]], random_pos_frac_proj
#         )
#         random_pos_cart_proj = torch.einsum(
#             "bi,bij->bj",
#             random_pos_frac_proj,
#             perm_conv_lat_proj[batch.batch[wyckoff_batch]],
#         )

#         random_fracs = torch.einsum(
#             "bi,bij->bj",
#             random_pos_cart_proj,
#             prim_lat_inv[batch.batch[wyckoff_batch]],
#         )
#         random_fracs = random_fracs % 1.0
#         random_fracs_diff = random_fracs.unsqueeze(1) - random_fracs.unsqueeze(0)
#         random_fracs_diff = random_fracs_diff - torch.round(random_fracs_diff)
#         EPSILON = 5e-4
#         random_fracs_diff_is_zero = torch.all(
#             torch.isclose(
#                 random_fracs_diff,
#                 torch.zeros_like(random_fracs_diff),
#                 rtol=EPSILON,
#                 atol=EPSILON,
#             ),
#             dim=-1,
#         )
#         random_fracs_idx = random_fracs_diff_is_zero & (
#             wyckoff_batch.unsqueeze(0) == wyckoff_batch.unsqueeze(1)
#         )
#         random_fracs_idx = ~(random_fracs_idx.triu(diagonal=1).any(dim=0))
#         # random_fracs_prim = random_fracs[random_fracs_idx]
#         assert random_fracs_idx.shape[0] == pos_prim_frac_proj_all.shape[0]
#         pos_prim_frac_proj = pos_prim_frac_proj_all[random_fracs_idx]
#         if pos_prim_frac_proj.shape[0] == batch.pos.shape[0]:
#             frac_batch = random_fracs_idx
#             break
#     pos_prim_frac_proj = pos_prim_frac_proj_all[frac_batch]

#     # prim_lat_proj = torch.bmm(torch.bmm(perm.transpose(-1,-2), prim_lat_proj),perm)
#     # pos_prim_frac_proj = torch.einsum("bij,bj->bi", perm.transpose(-1,-2), pos_prim_frac_proj)

#     return (pos_prim_frac_proj % 1.0), prim_lat_proj, pos_frac_proj % 1.0, perm_conv_lat_proj
# # Success for 6

# %%
def get_latttice_permutations(device="cpu"):
    lat_perm = np.zeros((231, 3, 3, 3, 3, 3))
    lat_perm[:, :, :, :, 0, 0] = 1
    lat_perm[:, :, :, :, 1, 1] = 1
    lat_perm[:, :, :, :, 2, 2] = 1
    # Ex) 1, 0, 2 implies lat(1) > lat(0) > lat(2)
    possible_perms = [[0, 1, 2], [0, 2, 1], [1, 0, 2], [1, 2, 0], [2, 0, 1], [2, 1, 0]]

    perm_for_A1 = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
    perm_for_A2 = lat_perm.copy()
    # lat_perm[:, 0, 1, 2] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
    # lat_perm[:, 0, 2, 1] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
    # lat_perm[:, 1, 0, 2] = np.array([[0, 0, 1], [1, 0, 0], [0, 1, 0]])
    # lat_perm[:, 1, 2, 0] = np.array([[1, 0, 0], [0, 0, 1], [0, 1, 0]])
    # lat_perm[:, 2, 0, 1] = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
    # lat_perm[:, 2, 1, 0] = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])

    # orthorhombic with A:
    for i in [38, 39, 40, 41]:
        # perm_for_A2[i, 0, 1, 2] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
        # perm_for_A2[i, 0, 2, 1] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        # perm_for_A2[i, 1, 0, 2] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
        # perm_for_A2[i, 1, 2, 0] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
        # perm_for_A2[i, 2, 0, 1] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        # perm_for_A2[i, 2, 1, 0] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        
        perm_for_A2[i, 0, 1, 2] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        perm_for_A2[i, 0, 2, 1] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
        perm_for_A2[i, 1, 0, 2] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        perm_for_A2[i, 1, 2, 0] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        perm_for_A2[i, 2, 0, 1] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])
        perm_for_A2[i, 2, 1, 0] = np.array([[0, 1, 0], [0, 0, 1], [1, 0, 0]])

        # perm_for_A2[i, 0, 1, 2] = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
        # perm_for_A2[i, 0, 2, 1] = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
        # perm_for_A2[i, 1, 0, 2] = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
        # perm_for_A2[i, 1, 2, 0] = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
        # perm_for_A2[i, 2, 0, 1] = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
        # perm_for_A2[i, 2, 1, 0] = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])

        lat_perm[i, 0, 1, 2] = np.array([[0, 0, 1], [1, 0, 0], [0, 1, 0]])
        lat_perm[i, 0, 2, 1] = np.array([[0, 0, 1], [1, 0, 0], [0, 1, 0]])
        lat_perm[i, 1, 0, 2] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        lat_perm[i, 1, 2, 0] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        lat_perm[i, 2, 0, 1] = np.array([[0, 0, 1], [1, 0, 0], [0, 1, 0]])
        lat_perm[i, 2, 1, 0] = np.array([[0, 0, 1], [0, 1, 0], [1, 0, 0]])
        # for p in possible_perms:
        #     lat_perm[i, p[0], p[1], p[2]] = perm_for_A1 @ lat_perm[0, p[0], p[1], p[2]]
        # perm_for_A2[i] = np.array([[1, 0, 0], [0, 0, 1], [0, 1, 0]])
    lat_perm = torch.tensor(lat_perm, dtype=torch.float32)
    perm_for_A1 = torch.tensor(perm_for_A1, dtype=torch.float32)
    perm_for_A2 = torch.tensor(perm_for_A2, dtype=torch.float32)
    return lat_perm.to(device), perm_for_A1.to(device), perm_for_A2.to(device)

def _project_to_space_group(batch,pos=None,cell=None):
    cf = CrystalFamily()
    cf.set_device(batch.pos.device)
    lat_perm, _, perm_for_A2 = get_latttice_permutations(device=batch.pos.device)
    if pos is not None:
        batch = batch.replace(pos=pos)
    else:
        batch = batch.replace(pos=torch.rand_like(batch.pos))
    if cell is not None:
        batch = batch.replace(cell=cell)
    else:
        batch = batch.replace(cell=torch.tensor(initialize_random_lattice().matrix).unsqueeze(0).float())

    wyckoff_batch = batch.wyckoff_bat.clone()
    idx, cum = 0, 0
    for len, num_atom in zip(batch.wyckoff_bat_len, batch.num_atoms):
        wyckoff_batch[idx : idx + len] = wyckoff_batch[idx : idx + len] + cum
        idx += len
        cum += num_atom

    # project latice
    conv_lat = torch.bmm(batch.prim_to_conv, batch.cell)
    conv_lat_vec = cf.m2v(cf.de_so3(conv_lat))
    conv_lat_vec_proj = cf.proj_k_to_spacegroup(conv_lat_vec, batch.space_groups)
    conv_lat_proj = cf.v2m(conv_lat_vec_proj)
    # print("conv_lat_proj") # The same
    # print(conv_lat_proj)

    rank = torch.argsort(-torch.norm(conv_lat_proj, dim=-1), dim=-1)
    idx = torch.cat([batch.space_groups.unsqueeze(-1), rank], dim=-1)
    # print(rank)
    perm = lat_perm[idx[:, 0], idx[:, 1], idx[:, 2], idx[:, 3]]
    # perm_A = perm_for_A2[batch.space_groups]    
    # perm = perm_for_A2[0].unsqueeze(0).repeat(batch.space_groups.shape[0], 1, 1)
    perm_conv_lat_proj = torch.bmm(torch.bmm(perm, conv_lat_proj), perm.transpose(-1, -2))
    # print("perm_conv_lat_proj")
    # print(perm_conv_lat_proj) # C, B, A
    
    
    rankA = torch.argsort(-torch.norm(perm_conv_lat_proj, dim=-1), dim=-1)
    idxA = torch.cat([batch.space_groups.unsqueeze(-1), rankA], dim=-1)
    permA = perm_for_A2[idxA[:, 0], idxA[:, 1], idxA[:, 2], idxA[:, 3]]
    # print("perm")
    # print(conv_lat_proj)
    # print(perm)
    # print(rank)
    # print("perm_conv_lat_proj")
    # print(perm_conv_lat_proj)
    # print(rankA)
    # print("permA")
    # print(permA)
    
    permA_conv_lat_proj = torch.bmm(torch.bmm(permA, perm_conv_lat_proj), permA.transpose(-1, -2))
    # print("permA_conv_lat_proj")
    # print(permA_conv_lat_proj)
    
    # Aligning the lattice vectors as the size of the lattice vectors
    # perm_conv_lat_proj = torch.bmm(
    #     torch.bmm(perm_A, perm_conv_lat_proj), perm_A.transpose(-1, -2)
    # )

    # perm_conv_lat_proj = conv_lat_proj

    # prim_lat_proj = torch.bmm(torch.bmm(torch.bmm(permA,batch.conv_to_prim),permA.transpose(-1,-2)), perm_conv_lat_proj)
    prim_lat_proj = torch.bmm(batch.conv_to_prim, permA_conv_lat_proj)
    
    pos_cart = torch.einsum("bi,bij->bj", batch.pos, batch.cell[batch.batch])
    # print(pos_cart)
    pos_cart = torch.einsum("bij,bj->bi", perm[batch.batch], pos_cart)
    pos_frac_conv = torch.einsum(
        "bi,bij->bj", pos_cart, torch.inverse(perm_conv_lat_proj)[batch.batch]
    )
    # print("inverse")
    pos_frac_conv = pos_frac_conv % 1.0
    pos_tran = torch.cat(
        [
            pos_frac_conv[wyckoff_batch],
            torch.ones(pos_frac_conv[wyckoff_batch].shape[0], 1, device=batch.pos.device),
        ],
        dim=1,
    )

    pos_frac_proj = (
        torch.einsum("bij,bj->bi", batch.wyckoff_ops, pos_tran).squeeze(-1)[:, :3] % 1.0
    )
    # trick = torch.tensor([0,1e-3,2e-3])
    trick = torch.tensor([0,0,0])
    # scatter(pos_frac_proj, batch.batch, dim=)
    # cannon_pos_frac_proj = pos_frac_proj[scatter_min((pos_frac_proj + trick).norm(dim=-1), wyckoff_batch, dim=0)[1][wyckoff_batch]]
    # pos_tran = torch.cat(
    #     [
    #         cannon_pos_frac_proj,
    #         torch.ones(cannon_pos_frac_proj.shape[0], 1, device=batch.pos.device),
    #     ]
    #     , dim=1
    # )
    # pos_frac_proj = (
    #     torch.einsum("bij,bj->bi", batch.wyckoff_ops, pos_tran).squeeze(-1)[:, :3] % 1.0
    # )
    
    # return pos_frac_proj, pos_frac_proj2
    pos_cart_proj = torch.einsum(
        "bi,bij->bj", pos_frac_proj, perm_conv_lat_proj[batch.batch[wyckoff_batch]]
    )
    prim_lat_proj = prim_lat_proj
    prim_lat_inv = torch.inverse(prim_lat_proj)
    pos_cart_proj = torch.einsum(
        "bij,bj->bi", permA[batch.batch[wyckoff_batch]], pos_cart_proj
    )
    pos_prim_frac_proj_all = torch.einsum(
        "bi,bij->bj", pos_cart_proj, prim_lat_inv[batch.batch[wyckoff_batch]]
    )

    ## Get prim idx
    for i in range(10):
        random_pos_frac_conv = torch.rand_like(pos_frac_conv).to(pos_frac_conv.device)
        random_pos_tran = torch.cat(
            [
                random_pos_frac_conv[wyckoff_batch],
                torch.ones(
                    random_pos_frac_conv[wyckoff_batch].shape[0],
                    1,
                    device=pos_frac_conv.device,
                ),
            ],
            dim=1,
        )
        random_pos_frac_proj = (
            torch.einsum("bij,bj->bi", batch.wyckoff_ops, random_pos_tran).squeeze(-1)[
                :, :3
            ]
            % 1.0
        ) % 1.0
        random_pos_cart_proj = torch.einsum(
            "bi,bij->bj",
            random_pos_frac_proj,
            perm_conv_lat_proj[batch.batch[wyckoff_batch]],
        )
        random_pos_cart_proj = torch.einsum(
        "bij,bj->bi", permA[batch.batch[wyckoff_batch]], random_pos_cart_proj
        )

        random_fracs = torch.einsum(
            "bi,bij->bj",
            random_pos_cart_proj,
            prim_lat_inv[batch.batch[wyckoff_batch]],
        )
        random_fracs = random_fracs % 1.0
        random_fracs_diff = random_fracs.unsqueeze(1) - random_fracs.unsqueeze(0)
        random_fracs_diff = random_fracs_diff - torch.round(random_fracs_diff)
        EPSILON = 5e-4
        random_fracs_diff_is_zero = torch.all(
            torch.isclose(
                random_fracs_diff,
                torch.zeros_like(random_fracs_diff),
                rtol=EPSILON,
                atol=EPSILON,
            ),
            dim=-1,
        )
        random_fracs_idx = random_fracs_diff_is_zero & (
            wyckoff_batch.unsqueeze(0) == wyckoff_batch.unsqueeze(1)
        )
        random_fracs_idx = ~(random_fracs_idx.triu(diagonal=1).any(dim=0))
        assert random_fracs_idx.shape[0] == pos_prim_frac_proj_all.shape[0]
        pos_prim_frac_proj = pos_prim_frac_proj_all[random_fracs_idx]
        if pos_prim_frac_proj.shape[0] == batch.pos.shape[0]:
            frac_batch = random_fracs_idx
            break
    pos_prim_frac_proj = pos_prim_frac_proj_all[frac_batch]


    return (pos_prim_frac_proj % 1.0) %1.0, prim_lat_proj, pos_frac_proj % 1.0, perm_conv_lat_proj

# %%
space_group_input = np.arange(1, 231).tolist()
info_path = "/home/holywater2/crystal_gen/mattergen/_my_scripts/space_group_info/prim/mp_20_val"

dataset = WyckoffDataset.from_space_group_list(
    space_group_infos_path=info_path,
    num_samples=1000,
    space_groups=39
)

# %%
pos_test = torch.rand_like(dataset[0].pos)
cell_test = torch.tensor(initialize_random_lattice().matrix).unsqueeze(0).float()

# %%
torch.tensor([0.3983, 0.2500, 0.0422]).norm()
# Out:
# tensor(0.4721)

# %%
torch.tensor([0.6017, 0.2500, 0.0422],).norm()
# Out:
# tensor(0.6529)

# %%
torch.tensor([0.3983, 0.2500, 0.0422]).norm()

# %%
n=0
while(n < 100):
    n += 1
    pos_test = torch.rand_like(dataset[991].pos)
    cell_test = torch.tensor(initialize_random_lattice().matrix).unsqueeze(0).float()
    a,b,c,d = _project_to_space_group(collate([dataset[991]]), pos=pos_test, cell=cell_test)
    x,y,z,w = _project_to_space_group(collate([dataset[991]]),a,b)
    print(a)
    print(x)
    print(b)
    print(y)
    print(c)
    print(z)
    if not torch.allclose(a,x,rtol=1e-3) or not torch.allclose(b,y,rtol=1e-3) or not torch.allclose(c,z,rtol=1e-3) or not torch.allclose(d,w,rtol=1e-3):
        print("Fail")

        break
# Out:
# perm
# tensor([[[7.7082, 0.0000, 0.0000],
#          [0.0000, 8.2345, 0.0000],
#          [0.0000, 0.0000, 6.1628]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[6.1628, 0.0000, 0.0000],
#          [0.0000, 8.2345, 0.0000],
#          [0.0000, 0.0000, 7.7082]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.7082, 0.0000, 0.0000],
#          [0.0000, 8.2345, 0.0000],
#          [0.0000, 0.0000, 6.1628]]])
# perm
# tensor([[[7.7082, 0.0000, 0.0000],
#          [0.0000, 8.2345, 0.0000],
#          [0.0000, 0.0000, 6.1628]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[6.1628, 0.0000, 0.0000],
#          [0.0000, 8.2345, 0.0000],
#          [0.0000, 0.0000, 7.7082]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.7082, 0.0000, 0.0000],
#          [0.0000, 8.2345, 0.0000],
#          [0.0000, 0.0000, 6.1628]]])
# tensor([[0.4512, 0.4512, 0.0000],
#         [0.1473, 0.1473, 0.5000],
#         [0.1891, 0.7522, 0.5000],
#         [0.7522, 0.1891, 0.5000]])
# tensor([[0.4512, 0.4512, 0.0000],
#         [0.1473, 0.1473, 0.5000],
#         [0.1891, 0.7522, 0.5000],
#         [0.7522, 0.1891, 0.5000]])
# tensor([[[ 3.8541, -4.1173,  0.0000],
#          [ 3.8541,  4.1173,  0.0000],
#          [ 0.0000,  0.0000,  6.1628]]])
# tensor([[[ 3.8541, -4.1173,  0.0000],
#          [ 3.8541,  4.1173,  0.0000],
#          [ 0.0000,  0.0000,  6.1628]]])
# tensor([[0.0000, 0.0000, 0.4512],
#         [0.0000, 0.5000, 0.9512],
#         [0.5000, 0.0000, 0.1473],
#         [0.5000, 0.5000, 0.6473],
#         [0.5000, 0.2815, 0.4706],
#         [0.5000, 0.7185, 0.4706],
#         [0.5000, 0.7815, 0.9706],
#         [0.5000, 0.2185, 0.9706]])
# tensor([[0.0000, 0.0000, 0.4512],
#         [0.0000, 0.5000, 0.9512],
#         [0.5000, 0.0000, 0.1473],
#         [0.5000, 0.5000, 0.6473],
#         [0.5000, 0.2815, 0.4706],
#         [0.5000, 0.7185, 0.4706],
#         [0.5000, 0.7815, 0.9706],
#         [0.5000, 0.2185, 0.9706]])
# perm
# tensor([[[ 7.2990,  0.0000,  0.0000],
#          [ 0.0000, 11.5299,  0.0000],
#          [ 0.0000,  0.0000,  5.6859]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.6859,  0.0000,  0.0000],
#          [ 0.0000, 11.5299,  0.0000],
#          [ 0.0000,  0.0000,  7.2990]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 7.2990,  0.0000,  0.0000],
#          [ 0.0000, 11.5299,  0.0000],
#          [ 0.0000,  0.0000,  5.6859]]])
# perm
# tensor([[[ 7.2990,  0.0000,  0.0000],
#          [ 0.0000, 11.5299,  0.0000],
#          [ 0.0000,  0.0000,  5.6859]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.6859,  0.0000,  0.0000],
#          [ 0.0000, 11.5299,  0.0000],
#          [ 0.0000,  0.0000,  7.2990]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 7.2990,  0.0000,  0.0000],
#          [ 0.0000, 11.5299,  0.0000],
#          [ 0.0000,  0.0000,  5.6859]]])
# tensor([[0.3812, 0.3812, 0.0000],
#         [0.1114, 0.1114, 0.5000],
#         [0.2028, 0.4430, 0.5000],
#         [0.4430, 0.2028, 0.5000]])
# tensor([[0.3812, 0.3812, 0.0000],
#         [0.1114, 0.1114, 0.5000],
#         [0.2028, 0.4430, 0.5000],
#         [0.4430, 0.2028, 0.5000]])
# tensor([[[ 3.6495, -5.7650,  0.0000],
#          [ 3.6495,  5.7650,  0.0000],
#          [ 0.0000,  0.0000,  5.6859]]])
# tensor([[[ 3.6495, -5.7650,  0.0000],
#          [ 3.6495,  5.7650,  0.0000],
#          [ 0.0000,  0.0000,  5.6859]]])
# tensor([[0.0000, 0.0000, 0.3812],
#         [0.0000, 0.5000, 0.8812],
#         [0.5000, 0.0000, 0.1114],
#         [0.5000, 0.5000, 0.6114],
#         [0.5000, 0.1201, 0.3229],
#         [0.5000, 0.8799, 0.3229],
#         [0.5000, 0.6201, 0.8229],
#         [0.5000, 0.3799, 0.8229]])
# tensor([[0.0000, 0.0000, 0.3812],
#         [0.0000, 0.5000, 0.8812],
#         [0.5000, 0.0000, 0.1114],
#         [0.5000, 0.5000, 0.6114],
#         [0.5000, 0.1201, 0.3229],
#         [0.5000, 0.8799, 0.3229],
#         [0.5000, 0.6201, 0.8229],
#         [0.5000, 0.3799, 0.8229]])
# perm
# tensor([[[ 8.9964,  0.0000,  0.0000],
#          [ 0.0000, 13.0443,  0.0000],
#          [ 0.0000,  0.0000,  6.7198]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.7198,  0.0000,  0.0000],
#          [ 0.0000, 13.0443,  0.0000],
#          [ 0.0000,  0.0000,  8.9964]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.9964,  0.0000,  0.0000],
#          [ 0.0000, 13.0443,  0.0000],
#          [ 0.0000,  0.0000,  6.7198]]])
# perm
# tensor([[[ 8.9964,  0.0000,  0.0000],
#          [ 0.0000, 13.0443,  0.0000],
#          [ 0.0000,  0.0000,  6.7198]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.7198,  0.0000,  0.0000],
#          [ 0.0000, 13.0443,  0.0000],
#          [ 0.0000,  0.0000,  8.9964]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.9964,  0.0000,  0.0000],
#          [ 0.0000, 13.0443,  0.0000],
#          [ 0.0000,  0.0000,  6.7198]]])
# tensor([[0.2269, 0.2269, 0.0000],
#         [0.3598, 0.3598, 0.5000],
#         [0.5658, 0.5274, 0.5000],
#         [0.5274, 0.5658, 0.5000]])
# tensor([[0.2269, 0.2269, 0.0000],
#         [0.3598, 0.3598, 0.5000],
#         [0.5658, 0.5274, 0.5000],
#         [0.5274, 0.5658, 0.5000]])
# tensor([[[ 4.4982, -6.5222,  0.0000],
#          [ 4.4982,  6.5222,  0.0000],
#          [ 0.0000,  0.0000,  6.7198]]])
# tensor([[[ 4.4982, -6.5222,  0.0000],
#          [ 4.4982,  6.5222,  0.0000],
#          [ 0.0000,  0.0000,  6.7198]]])
# tensor([[0.0000, 0.0000, 0.2269],
#         [0.0000, 0.5000, 0.7269],
#         [0.5000, 0.0000, 0.3598],
#         [0.5000, 0.5000, 0.8598],
#         [0.5000, 0.4808, 0.0466],
#         [0.5000, 0.5192, 0.0466],
#         [0.5000, 0.9808, 0.5466],
#         [0.5000, 0.0192, 0.5466]])
# tensor([[0.0000, 0.0000, 0.2269],
#         [0.0000, 0.5000, 0.7269],
#         [0.5000, 0.0000, 0.3598],
#         [0.5000, 0.5000, 0.8598],
#         [0.5000, 0.4808, 0.0466],
#         [0.5000, 0.5192, 0.0466],
#         [0.5000, 0.9808, 0.5466],
#         [0.5000, 0.0192, 0.5466]])
# perm
# tensor([[[7.0480, 0.0000, 0.0000],
#          [0.0000, 9.4901, 0.0000],
#          [0.0000, 0.0000, 6.7865]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[6.7865, 0.0000, 0.0000],
#          [0.0000, 9.4901, 0.0000],
#          [0.0000, 0.0000, 7.0480]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.0480, 0.0000, 0.0000],
#          [0.0000, 9.4901, 0.0000],
#          [0.0000, 0.0000, 6.7865]]])
# perm
# tensor([[[7.0480, 0.0000, 0.0000],
#          [0.0000, 9.4901, 0.0000],
#          [0.0000, 0.0000, 6.7865]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[6.7865, 0.0000, 0.0000],
#          [0.0000, 9.4901, 0.0000],
#          [0.0000, 0.0000, 7.0480]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.0480, 0.0000, 0.0000],
#          [0.0000, 9.4901, 0.0000],
#          [0.0000, 0.0000, 6.7865]]])
# tensor([[0.1800, 0.1800, 0.0000],
#         [0.0538, 0.0538, 0.5000],
#         [0.9578, 0.2497, 0.5000],
#         [0.2497, 0.9578, 0.5000]])
# tensor([[0.1800, 0.1800, 0.0000],
#         [0.0538, 0.0538, 0.5000],
#         [0.9578, 0.2497, 0.5000],
#         [0.2497, 0.9578, 0.5000]])
# tensor([[[ 3.5240, -4.7451,  0.0000],
#          [ 3.5240,  4.7451,  0.0000],
#          [ 0.0000,  0.0000,  6.7865]]])
# tensor([[[ 3.5240, -4.7451,  0.0000],
#          [ 3.5240,  4.7451,  0.0000],
#          [ 0.0000,  0.0000,  6.7865]]])
# tensor([[0.0000, 0.0000, 0.1800],
#         [0.0000, 0.5000, 0.6800],
#         [0.5000, 0.0000, 0.0538],
#         [0.5000, 0.5000, 0.5538],
#         [0.5000, 0.1459, 0.1038],
#         [0.5000, 0.8541, 0.1038],
#         [0.5000, 0.6459, 0.6038],
#         [0.5000, 0.3541, 0.6038]])
# tensor([[0.0000, 0.0000, 0.1800],
#         [0.0000, 0.5000, 0.6800],
#         [0.5000, 0.0000, 0.0538],
#         [0.5000, 0.5000, 0.5538],
#         [0.5000, 0.1459, 0.1038],
#         [0.5000, 0.8541, 0.1038],
#         [0.5000, 0.6459, 0.6038],
#         [0.5000, 0.3541, 0.6038]])
# perm
# tensor([[[8.0993, 0.0000, 0.0000],
#          [0.0000, 9.2073, 0.0000],
#          [0.0000, 0.0000, 5.6348]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[5.6348, 0.0000, 0.0000],
#          [0.0000, 9.2073, 0.0000],
#          [0.0000, 0.0000, 8.0993]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[8.0993, 0.0000, 0.0000],
#          [0.0000, 9.2073, 0.0000],
#          [0.0000, 0.0000, 5.6348]]])
# perm
# tensor([[[8.0993, 0.0000, 0.0000],
#          [0.0000, 9.2073, 0.0000],
#          [0.0000, 0.0000, 5.6348]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[5.6348, 0.0000, 0.0000],
#          [0.0000, 9.2073, 0.0000],
#          [0.0000, 0.0000, 8.0993]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[8.0993, 0.0000, 0.0000],
#          [0.0000, 9.2073, 0.0000],
#          [0.0000, 0.0000, 5.6348]]])
# tensor([[0.0822, 0.0822, 0.0000],
#         [0.3616, 0.3616, 0.5000],
#         [0.9928, 0.0557, 0.5000],
#         [0.0557, 0.9928, 0.5000]])
# tensor([[0.0822, 0.0822, 0.0000],
#         [0.3616, 0.3616, 0.5000],
#         [0.9928, 0.0557, 0.5000],
#         [0.0557, 0.9928, 0.5000]])
# tensor([[[ 4.0497, -4.6036,  0.0000],
#          [ 4.0497,  4.6036,  0.0000],
#          [ 0.0000,  0.0000,  5.6348]]])
# tensor([[[ 4.0497, -4.6036,  0.0000],
#          [ 4.0497,  4.6036,  0.0000],
#          [ 0.0000,  0.0000,  5.6348]]])
# tensor([[0.0000, 0.0000, 0.0822],
#         [0.0000, 0.5000, 0.5822],
#         [0.5000, 0.0000, 0.3616],
#         [0.5000, 0.5000, 0.8616],
#         [0.5000, 0.0315, 0.0242],
#         [0.5000, 0.9685, 0.0242],
#         [0.5000, 0.5315, 0.5242],
#         [0.5000, 0.4685, 0.5242]])
# tensor([[0.0000, 0.0000, 0.0822],
#         [0.0000, 0.5000, 0.5822],
#         [0.5000, 0.0000, 0.3616],
#         [0.5000, 0.5000, 0.8616],
#         [0.5000, 0.0315, 0.0242],
#         [0.5000, 0.9685, 0.0242],
#         [0.5000, 0.5315, 0.5242],
#         [0.5000, 0.4685, 0.5242]])
# perm
# tensor([[[5.8755, 0.0000, 0.0000],
#          [0.0000, 8.3596, 0.0000],
#          [0.0000, 0.0000, 5.4370]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[5.4370, 0.0000, 0.0000],
#          [0.0000, 8.3596, 0.0000],
#          [0.0000, 0.0000, 5.8755]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[5.8755, 0.0000, 0.0000],
#          [0.0000, 8.3596, 0.0000],
#          [0.0000, 0.0000, 5.4370]]])
# perm
# tensor([[[5.8755, 0.0000, 0.0000],
#          [0.0000, 8.3596, 0.0000],
#          [0.0000, 0.0000, 5.4370]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[5.4370, 0.0000, 0.0000],
#          [0.0000, 8.3596, 0.0000],
#          [0.0000, 0.0000, 5.8755]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[5.8755, 0.0000, 0.0000],
#          [0.0000, 8.3596, 0.0000],
#          [0.0000, 0.0000, 5.4370]]])
# tensor([[0.2731, 0.2731, 0.0000],
#         [0.3723, 0.3723, 0.5000],
#         [0.6554, 0.3764, 0.5000],
#         [0.3764, 0.6554, 0.5000]])
# tensor([[0.2731, 0.2731, 0.0000],
#         [0.3723, 0.3723, 0.5000],
#         [0.6554, 0.3764, 0.5000],
#         [0.3764, 0.6554, 0.5000]])
# tensor([[[ 2.9377, -4.1798,  0.0000],
#          [ 2.9377,  4.1798,  0.0000],
#          [ 0.0000,  0.0000,  5.4370]]])
# tensor([[[ 2.9377, -4.1798,  0.0000],
#          [ 2.9377,  4.1798,  0.0000],
#          [ 0.0000,  0.0000,  5.4370]]])
# tensor([[0.0000, 0.0000, 0.2731],
#         [0.0000, 0.5000, 0.7731],
#         [0.5000, 0.0000, 0.3723],
#         [0.5000, 0.5000, 0.8723],
#         [0.5000, 0.3605, 0.0159],
#         [0.5000, 0.6395, 0.0159],
#         [0.5000, 0.8605, 0.5159],
#         [0.5000, 0.1395, 0.5159]])
# tensor([[0.0000, 0.0000, 0.2731],
#         [0.0000, 0.5000, 0.7731],
#         [0.5000, 0.0000, 0.3723],
#         [0.5000, 0.5000, 0.8723],
#         [0.5000, 0.3605, 0.0159],
#         [0.5000, 0.6395, 0.0159],
#         [0.5000, 0.8605, 0.5159],
#         [0.5000, 0.1395, 0.5159]])
# perm
# tensor([[[ 6.8594,  0.0000,  0.0000],
#          [ 0.0000, 11.0992,  0.0000],
#          [ 0.0000,  0.0000,  6.5861]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.5861,  0.0000,  0.0000],
#          [ 0.0000, 11.0992,  0.0000],
#          [ 0.0000,  0.0000,  6.8594]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 6.8594,  0.0000,  0.0000],
#          [ 0.0000, 11.0992,  0.0000],
#          [ 0.0000,  0.0000,  6.5861]]])
# perm
# tensor([[[ 6.8594,  0.0000,  0.0000],
#          [ 0.0000, 11.0992,  0.0000],
#          [ 0.0000,  0.0000,  6.5861]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.5861,  0.0000,  0.0000],
#          [ 0.0000, 11.0992,  0.0000],
#          [ 0.0000,  0.0000,  6.8594]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 6.8594,  0.0000,  0.0000],
#          [ 0.0000, 11.0992,  0.0000],
#          [ 0.0000,  0.0000,  6.5861]]])
# tensor([[0.2742, 0.2742, 0.0000],
#         [0.4587, 0.4587, 0.5000],
#         [0.2049, 0.3852, 0.5000],
#         [0.3852, 0.2049, 0.5000]])
# tensor([[0.2742, 0.2742, 0.0000],
#         [0.4587, 0.4587, 0.5000],
#         [0.2049, 0.3852, 0.5000],
#         [0.3852, 0.2049, 0.5000]])
# tensor([[[ 3.4297, -5.5496,  0.0000],
#          [ 3.4297,  5.5496,  0.0000],
#          [ 0.0000,  0.0000,  6.5861]]])
# tensor([[[ 3.4297, -5.5496,  0.0000],
#          [ 3.4297,  5.5496,  0.0000],
#          [ 0.0000,  0.0000,  6.5861]]])
# tensor([[0.0000, 0.0000, 0.2742],
#         [0.0000, 0.5000, 0.7742],
#         [0.5000, 0.0000, 0.4587],
#         [0.5000, 0.5000, 0.9587],
#         [0.5000, 0.0901, 0.2951],
#         [0.5000, 0.9099, 0.2951],
#         [0.5000, 0.5901, 0.7951],
#         [0.5000, 0.4099, 0.7951]])
# tensor([[0.0000, 0.0000, 0.2742],
#         [0.0000, 0.5000, 0.7742],
#         [0.5000, 0.0000, 0.4587],
#         [0.5000, 0.5000, 0.9587],
#         [0.5000, 0.0901, 0.2951],
#         [0.5000, 0.9099, 0.2951],
#         [0.5000, 0.5901, 0.7951],
#         [0.5000, 0.4099, 0.7951]])
# perm
# tensor([[[11.0137,  0.0000,  0.0000],
#          [ 0.0000, 15.9260,  0.0000],
#          [ 0.0000,  0.0000,  7.3287]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.3287,  0.0000,  0.0000],
#          [ 0.0000, 15.9260,  0.0000],
#          [ 0.0000,  0.0000, 11.0137]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[11.0137,  0.0000,  0.0000],
#          [ 0.0000, 15.9260,  0.0000],
#          [ 0.0000,  0.0000,  7.3287]]])
# perm
# tensor([[[11.0137,  0.0000,  0.0000],
#          [ 0.0000, 15.9260,  0.0000],
#          [ 0.0000,  0.0000,  7.3287]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.3287,  0.0000,  0.0000],
#          [ 0.0000, 15.9260,  0.0000],
#          [ 0.0000,  0.0000, 11.0137]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[11.0137,  0.0000,  0.0000],
#          [ 0.0000, 15.9260,  0.0000],
#          [ 0.0000,  0.0000,  7.3287]]])
# tensor([[0.3212, 0.3212, 0.0000],
#         [0.0694, 0.0694, 0.5000],
#         [0.2467, 0.7039, 0.5000],
#         [0.7039, 0.2467, 0.5000]])
# tensor([[0.3212, 0.3212, 0.0000],
#         [0.0694, 0.0694, 0.5000],
#         [0.2467, 0.7039, 0.5000],
#         [0.7039, 0.2467, 0.5000]])
# tensor([[[ 5.5068, -7.9630,  0.0000],
#          [ 5.5068,  7.9630,  0.0000],
#          [ 0.0000,  0.0000,  7.3287]]])
# tensor([[[ 5.5068, -7.9630,  0.0000],
#          [ 5.5068,  7.9630,  0.0000],
#          [ 0.0000,  0.0000,  7.3287]]])
# tensor([[0.0000, 0.0000, 0.3212],
#         [0.0000, 0.5000, 0.8212],
#         [0.5000, 0.0000, 0.0694],
#         [0.5000, 0.5000, 0.5694],
#         [0.5000, 0.2286, 0.4753],
#         [0.5000, 0.7714, 0.4753],
#         [0.5000, 0.7286, 0.9753],
#         [0.5000, 0.2714, 0.9753]])
# tensor([[0.0000, 0.0000, 0.3212],
#         [0.0000, 0.5000, 0.8212],
#         [0.5000, 0.0000, 0.0694],
#         [0.5000, 0.5000, 0.5694],
#         [0.5000, 0.2286, 0.4753],
#         [0.5000, 0.7714, 0.4753],
#         [0.5000, 0.7286, 0.9753],
#         [0.5000, 0.2714, 0.9753]])
# perm
# tensor([[[9.4019, 0.0000, 0.0000],
#          [0.0000, 6.4622, 0.0000],
#          [0.0000, 0.0000, 7.8695]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 2, 1]])
# perm_conv_lat_proj
# tensor([[[7.8695, 0.0000, 0.0000],
#          [0.0000, 9.4019, 0.0000],
#          [0.0000, 0.0000, 6.4622]]])
# tensor([[1, 0, 2]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[6.4622, 0.0000, 0.0000],
#          [0.0000, 9.4019, 0.0000],
#          [0.0000, 0.0000, 7.8695]]])
# perm
# tensor([[[6.4622, 0.0000, 0.0000],
#          [0.0000, 9.4019, 0.0000],
#          [0.0000, 0.0000, 7.8695]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 2, 0]])
# perm_conv_lat_proj
# tensor([[[7.8695, 0.0000, 0.0000],
#          [0.0000, 9.4019, 0.0000],
#          [0.0000, 0.0000, 6.4622]]])
# tensor([[1, 0, 2]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[6.4622, 0.0000, 0.0000],
#          [0.0000, 9.4019, 0.0000],
#          [0.0000, 0.0000, 7.8695]]])
# tensor([[0.4016, 0.4016, 0.0000],
#         [0.1278, 0.1278, 0.5000],
#         [0.5455, 0.4893, 0.5000],
#         [0.4893, 0.5455, 0.5000]])
# tensor([[0.4016, 0.4016, 0.0000],
#         [0.1278, 0.1278, 0.5000],
#         [0.5455, 0.4893, 0.5000],
#         [0.4893, 0.5455, 0.5000]])
# tensor([[[ 3.2311, -4.7010,  0.0000],
#          [ 3.2311,  4.7010,  0.0000],
#          [ 0.0000,  0.0000,  7.8695]]])
# tensor([[[ 3.2311, -4.7010,  0.0000],
#          [ 3.2311,  4.7010,  0.0000],
#          [ 0.0000,  0.0000,  7.8695]]])
# tensor([[0.0000, 0.0000, 0.4016],
#         [0.0000, 0.5000, 0.9016],
#         [0.5000, 0.0000, 0.1278],
#         [0.5000, 0.5000, 0.6278],
#         [0.5000, 0.4719, 0.0174],
#         [0.5000, 0.5281, 0.0174],
#         [0.5000, 0.9719, 0.5174],
#         [0.5000, 0.0281, 0.5174]])
# tensor([[0.0000, 0.0000, 0.4016],
#         [0.0000, 0.5000, 0.9016],
#         [0.5000, 0.0000, 0.1278],
#         [0.5000, 0.5000, 0.6278],
#         [0.5000, 0.4719, 0.0174],
#         [0.5000, 0.5281, 0.0174],
#         [0.5000, 0.9719, 0.5174],
#         [0.5000, 0.0281, 0.5174]])
# perm
# tensor([[[12.3766,  0.0000,  0.0000],
#          [ 0.0000, 14.6958,  0.0000],
#          [ 0.0000,  0.0000,  6.7716]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.7716,  0.0000,  0.0000],
#          [ 0.0000, 14.6958,  0.0000],
#          [ 0.0000,  0.0000, 12.3766]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[12.3766,  0.0000,  0.0000],
#          [ 0.0000, 14.6958,  0.0000],
#          [ 0.0000,  0.0000,  6.7716]]])
# perm
# tensor([[[12.3766,  0.0000,  0.0000],
#          [ 0.0000, 14.6958,  0.0000],
#          [ 0.0000,  0.0000,  6.7716]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.7716,  0.0000,  0.0000],
#          [ 0.0000, 14.6958,  0.0000],
#          [ 0.0000,  0.0000, 12.3766]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[12.3766,  0.0000,  0.0000],
#          [ 0.0000, 14.6958,  0.0000],
#          [ 0.0000,  0.0000,  6.7716]]])
# tensor([[0.4571, 0.4571, 0.0000],
#         [0.4702, 0.4702, 0.5000],
#         [0.5988, 0.4370, 0.5000],
#         [0.4370, 0.5988, 0.5000]])
# tensor([[0.4571, 0.4571, 0.0000],
#         [0.4702, 0.4702, 0.5000],
#         [0.5988, 0.4370, 0.5000],
#         [0.4370, 0.5988, 0.5000]])
# tensor([[[ 6.1883, -7.3479,  0.0000],
#          [ 6.1883,  7.3479,  0.0000],
#          [ 0.0000,  0.0000,  6.7716]]])
# tensor([[[ 6.1883, -7.3479,  0.0000],
#          [ 6.1883,  7.3479,  0.0000],
#          [ 0.0000,  0.0000,  6.7716]]])
# tensor([[0.0000, 0.0000, 0.4571],
#         [0.0000, 0.5000, 0.9571],
#         [0.5000, 0.0000, 0.4702],
#         [0.5000, 0.5000, 0.9702],
#         [0.5000, 0.4191, 0.0179],
#         [0.5000, 0.5809, 0.0179],
#         [0.5000, 0.9191, 0.5179],
#         [0.5000, 0.0809, 0.5179]])
# tensor([[0.0000, 0.0000, 0.4571],
#         [0.0000, 0.5000, 0.9571],
#         [0.5000, 0.0000, 0.4702],
#         [0.5000, 0.5000, 0.9702],
#         [0.5000, 0.4191, 0.0179],
#         [0.5000, 0.5809, 0.0179],
#         [0.5000, 0.9191, 0.5179],
#         [0.5000, 0.0809, 0.5179]])
# perm
# tensor([[[ 8.7979,  0.0000,  0.0000],
#          [ 0.0000, 12.9394,  0.0000],
#          [ 0.0000,  0.0000,  5.4093]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.4093,  0.0000,  0.0000],
#          [ 0.0000, 12.9394,  0.0000],
#          [ 0.0000,  0.0000,  8.7979]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.7979,  0.0000,  0.0000],
#          [ 0.0000, 12.9394,  0.0000],
#          [ 0.0000,  0.0000,  5.4093]]])
# perm
# tensor([[[ 8.7979,  0.0000,  0.0000],
#          [ 0.0000, 12.9394,  0.0000],
#          [ 0.0000,  0.0000,  5.4093]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.4093,  0.0000,  0.0000],
#          [ 0.0000, 12.9394,  0.0000],
#          [ 0.0000,  0.0000,  8.7979]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.7979,  0.0000,  0.0000],
#          [ 0.0000, 12.9394,  0.0000],
#          [ 0.0000,  0.0000,  5.4093]]])
# tensor([[0.3681, 0.3681, 0.0000],
#         [0.3604, 0.3604, 0.5000],
#         [0.7932, 0.2824, 0.5000],
#         [0.2824, 0.7932, 0.5000]])
# tensor([[0.3681, 0.3681, 0.0000],
#         [0.3604, 0.3604, 0.5000],
#         [0.7932, 0.2824, 0.5000],
#         [0.2824, 0.7932, 0.5000]])
# tensor([[[ 4.3990, -6.4697,  0.0000],
#          [ 4.3990,  6.4697,  0.0000],
#          [ 0.0000,  0.0000,  5.4093]]])
# tensor([[[ 4.3990, -6.4697,  0.0000],
#          [ 4.3990,  6.4697,  0.0000],
#          [ 0.0000,  0.0000,  5.4093]]])
# tensor([[0.0000, 0.0000, 0.3681],
#         [0.0000, 0.5000, 0.8681],
#         [0.5000, 0.0000, 0.3604],
#         [0.5000, 0.5000, 0.8604],
#         [0.5000, 0.2446, 0.0378],
#         [0.5000, 0.7554, 0.0378],
#         [0.5000, 0.7446, 0.5378],
#         [0.5000, 0.2554, 0.5378]])
# tensor([[0.0000, 0.0000, 0.3681],
#         [0.0000, 0.5000, 0.8681],
#         [0.5000, 0.0000, 0.3604],
#         [0.5000, 0.5000, 0.8604],
#         [0.5000, 0.2446, 0.0378],
#         [0.5000, 0.7554, 0.0378],
#         [0.5000, 0.7446, 0.5378],
#         [0.5000, 0.2554, 0.5378]])
# perm
# tensor([[[7.6012, 0.0000, 0.0000],
#          [0.0000, 9.9751, 0.0000],
#          [0.0000, 0.0000, 6.7237]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[6.7237, 0.0000, 0.0000],
#          [0.0000, 9.9751, 0.0000],
#          [0.0000, 0.0000, 7.6012]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.6012, 0.0000, 0.0000],
#          [0.0000, 9.9751, 0.0000],
#          [0.0000, 0.0000, 6.7237]]])
# perm
# tensor([[[7.6012, 0.0000, 0.0000],
#          [0.0000, 9.9751, 0.0000],
#          [0.0000, 0.0000, 6.7237]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[6.7237, 0.0000, 0.0000],
#          [0.0000, 9.9751, 0.0000],
#          [0.0000, 0.0000, 7.6012]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.6012, 0.0000, 0.0000],
#          [0.0000, 9.9751, 0.0000],
#          [0.0000, 0.0000, 6.7237]]])
# tensor([[0.0475, 0.0475, 0.0000],
#         [0.0950, 0.0950, 0.5000],
#         [0.9919, 0.9797, 0.5000],
#         [0.9797, 0.9919, 0.5000]])
# tensor([[0.0475, 0.0475, 0.0000],
#         [0.0950, 0.0950, 0.5000],
#         [0.9919, 0.9797, 0.5000],
#         [0.9797, 0.9919, 0.5000]])
# tensor([[[ 3.8006, -4.9875,  0.0000],
#          [ 3.8006,  4.9875,  0.0000],
#          [ 0.0000,  0.0000,  6.7237]]])
# tensor([[[ 3.8006, -4.9875,  0.0000],
#          [ 3.8006,  4.9875,  0.0000],
#          [ 0.0000,  0.0000,  6.7237]]])
# tensor([[0.0000, 0.0000, 0.0475],
#         [0.0000, 0.5000, 0.5475],
#         [0.5000, 0.0000, 0.0950],
#         [0.5000, 0.5000, 0.5950],
#         [0.5000, 0.4939, 0.4858],
#         [0.5000, 0.5061, 0.4858],
#         [0.5000, 0.9939, 0.9858],
#         [0.5000, 0.0061, 0.9858]])
# tensor([[0.0000, 0.0000, 0.0475],
#         [0.0000, 0.5000, 0.5475],
#         [0.5000, 0.0000, 0.0950],
#         [0.5000, 0.5000, 0.5950],
#         [0.5000, 0.4939, 0.4858],
#         [0.5000, 0.5061, 0.4858],
#         [0.5000, 0.9939, 0.9858],
#         [0.5000, 0.0061, 0.9858]])
# perm
# tensor([[[11.1357,  0.0000,  0.0000],
#          [ 0.0000, 10.5385,  0.0000],
#          [ 0.0000,  0.0000,  6.9556]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 1, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.9556,  0.0000,  0.0000],
#          [ 0.0000, 11.1357,  0.0000],
#          [ 0.0000,  0.0000, 10.5385]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.5385,  0.0000,  0.0000],
#          [ 0.0000, 11.1357,  0.0000],
#          [ 0.0000,  0.0000,  6.9556]]])
# perm
# tensor([[[10.5385,  0.0000,  0.0000],
#          [ 0.0000, 11.1357,  0.0000],
#          [ 0.0000,  0.0000,  6.9556]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.9556,  0.0000,  0.0000],
#          [ 0.0000, 11.1357,  0.0000],
#          [ 0.0000,  0.0000, 10.5385]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.5385,  0.0000,  0.0000],
#          [ 0.0000, 11.1357,  0.0000],
#          [ 0.0000,  0.0000,  6.9556]]])
# tensor([[0.2518, 0.2518, 0.0000],
#         [0.2619, 0.2619, 0.5000],
#         [0.7990, 0.5966, 0.5000],
#         [0.5966, 0.7990, 0.5000]])
# tensor([[0.2518, 0.2518, 0.0000],
#         [0.2619, 0.2619, 0.5000],
#         [0.7990, 0.5966, 0.5000],
#         [0.5966, 0.7990, 0.5000]])
# tensor([[[ 5.2692, -5.5678,  0.0000],
#          [ 5.2692,  5.5678,  0.0000],
#          [ 0.0000,  0.0000,  6.9556]]])
# tensor([[[ 5.2692, -5.5678,  0.0000],
#          [ 5.2692,  5.5678,  0.0000],
#          [ 0.0000,  0.0000,  6.9556]]])
# tensor([[0.0000, 0.0000, 0.2518],
#         [0.0000, 0.5000, 0.7518],
#         [0.5000, 0.0000, 0.2619],
#         [0.5000, 0.5000, 0.7619],
#         [0.5000, 0.3988, 0.1978],
#         [0.5000, 0.6012, 0.1978],
#         [0.5000, 0.8988, 0.6978],
#         [0.5000, 0.1012, 0.6978]])
# tensor([[0.0000, 0.0000, 0.2518],
#         [0.0000, 0.5000, 0.7518],
#         [0.5000, 0.0000, 0.2619],
#         [0.5000, 0.5000, 0.7619],
#         [0.5000, 0.3988, 0.1978],
#         [0.5000, 0.6012, 0.1978],
#         [0.5000, 0.8988, 0.6978],
#         [0.5000, 0.1012, 0.6978]])
# perm
# tensor([[[ 7.7616,  0.0000,  0.0000],
#          [ 0.0000, 10.4343,  0.0000],
#          [ 0.0000,  0.0000,  4.7287]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 4.7287,  0.0000,  0.0000],
#          [ 0.0000, 10.4343,  0.0000],
#          [ 0.0000,  0.0000,  7.7616]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 7.7616,  0.0000,  0.0000],
#          [ 0.0000, 10.4343,  0.0000],
#          [ 0.0000,  0.0000,  4.7287]]])
# perm
# tensor([[[ 7.7616,  0.0000,  0.0000],
#          [ 0.0000, 10.4343,  0.0000],
#          [ 0.0000,  0.0000,  4.7287]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 4.7287,  0.0000,  0.0000],
#          [ 0.0000, 10.4343,  0.0000],
#          [ 0.0000,  0.0000,  7.7616]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 7.7616,  0.0000,  0.0000],
#          [ 0.0000, 10.4343,  0.0000],
#          [ 0.0000,  0.0000,  4.7287]]])
# tensor([[0.1416, 0.1416, 0.0000],
#         [0.1948, 0.1948, 0.5000],
#         [0.1104, 0.8676, 0.5000],
#         [0.8676, 0.1104, 0.5000]])
# tensor([[0.1416, 0.1416, 0.0000],
#         [0.1948, 0.1948, 0.5000],
#         [0.1104, 0.8676, 0.5000],
#         [0.8676, 0.1104, 0.5000]])
# tensor([[[ 3.8808, -5.2171,  0.0000],
#          [ 3.8808,  5.2171,  0.0000],
#          [ 0.0000,  0.0000,  4.7287]]])
# tensor([[[ 3.8808, -5.2171,  0.0000],
#          [ 3.8808,  5.2171,  0.0000],
#          [ 0.0000,  0.0000,  4.7287]]])
# tensor([[0.0000, 0.0000, 0.1416],
#         [0.0000, 0.5000, 0.6416],
#         [0.5000, 0.0000, 0.1948],
#         [0.5000, 0.5000, 0.6948],
#         [0.5000, 0.3786, 0.4890],
#         [0.5000, 0.6214, 0.4890],
#         [0.5000, 0.8786, 0.9890],
#         [0.5000, 0.1214, 0.9890]])
# tensor([[0.0000, 0.0000, 0.1416],
#         [0.0000, 0.5000, 0.6416],
#         [0.5000, 0.0000, 0.1949],
#         [0.5000, 0.5000, 0.6949],
#         [0.5000, 0.3786, 0.4890],
#         [0.5000, 0.6214, 0.4890],
#         [0.5000, 0.8786, 0.9890],
#         [0.5000, 0.1214, 0.9890]])
# perm
# tensor([[[9.6764, 0.0000, 0.0000],
#          [0.0000, 8.6018, 0.0000],
#          [0.0000, 0.0000, 6.6308]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 1, 2]])
# perm_conv_lat_proj
# tensor([[[6.6308, 0.0000, 0.0000],
#          [0.0000, 9.6764, 0.0000],
#          [0.0000, 0.0000, 8.6018]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[8.6018, 0.0000, 0.0000],
#          [0.0000, 9.6764, 0.0000],
#          [0.0000, 0.0000, 6.6308]]])
# perm
# tensor([[[8.6018, 0.0000, 0.0000],
#          [0.0000, 9.6764, 0.0000],
#          [0.0000, 0.0000, 6.6308]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[6.6308, 0.0000, 0.0000],
#          [0.0000, 9.6764, 0.0000],
#          [0.0000, 0.0000, 8.6018]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[8.6018, 0.0000, 0.0000],
#          [0.0000, 9.6764, 0.0000],
#          [0.0000, 0.0000, 6.6308]]])
# tensor([[0.4163, 0.4163, 0.0000],
#         [0.0791, 0.0791, 0.5000],
#         [0.1167, 0.7821, 0.5000],
#         [0.7821, 0.1167, 0.5000]])
# tensor([[0.4163, 0.4163, 0.0000],
#         [0.0791, 0.0791, 0.5000],
#         [0.1167, 0.7821, 0.5000],
#         [0.7821, 0.1167, 0.5000]])
# tensor([[[ 4.3009, -4.8382,  0.0000],
#          [ 4.3009,  4.8382,  0.0000],
#          [ 0.0000,  0.0000,  6.6308]]])
# tensor([[[ 4.3009, -4.8382,  0.0000],
#          [ 4.3009,  4.8382,  0.0000],
#          [ 0.0000,  0.0000,  6.6308]]])
# tensor([[0.0000, 0.0000, 0.4163],
#         [0.0000, 0.5000, 0.9163],
#         [0.5000, 0.0000, 0.0791],
#         [0.5000, 0.5000, 0.5791],
#         [0.5000, 0.3327, 0.4494],
#         [0.5000, 0.6673, 0.4494],
#         [0.5000, 0.8327, 0.9494],
#         [0.5000, 0.1673, 0.9494]])
# tensor([[0.0000, 0.0000, 0.4163],
#         [0.0000, 0.5000, 0.9163],
#         [0.5000, 0.0000, 0.0791],
#         [0.5000, 0.5000, 0.5791],
#         [0.5000, 0.3327, 0.4494],
#         [0.5000, 0.6673, 0.4494],
#         [0.5000, 0.8327, 0.9494],
#         [0.5000, 0.1673, 0.9494]])
# perm
# tensor([[[10.4075,  0.0000,  0.0000],
#          [ 0.0000,  8.7003,  0.0000],
#          [ 0.0000,  0.0000,  8.2102]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 1, 2]])
# perm_conv_lat_proj
# tensor([[[ 8.2102,  0.0000,  0.0000],
#          [ 0.0000, 10.4075,  0.0000],
#          [ 0.0000,  0.0000,  8.7003]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.7003,  0.0000,  0.0000],
#          [ 0.0000, 10.4075,  0.0000],
#          [ 0.0000,  0.0000,  8.2102]]])
# perm
# tensor([[[ 8.7003,  0.0000,  0.0000],
#          [ 0.0000, 10.4075,  0.0000],
#          [ 0.0000,  0.0000,  8.2102]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 8.2102,  0.0000,  0.0000],
#          [ 0.0000, 10.4075,  0.0000],
#          [ 0.0000,  0.0000,  8.7003]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.7003,  0.0000,  0.0000],
#          [ 0.0000, 10.4075,  0.0000],
#          [ 0.0000,  0.0000,  8.2102]]])
# tensor([[0.4315, 0.4315, 0.0000],
#         [0.4699, 0.4699, 0.5000],
#         [0.9002, 0.2929, 0.5000],
#         [0.2929, 0.9002, 0.5000]])
# tensor([[0.4315, 0.4315, 0.0000],
#         [0.4699, 0.4699, 0.5000],
#         [0.9002, 0.2929, 0.5000],
#         [0.2929, 0.9002, 0.5000]])
# tensor([[[ 4.3501, -5.2037,  0.0000],
#          [ 4.3501,  5.2037,  0.0000],
#          [ 0.0000,  0.0000,  8.2102]]])
# tensor([[[ 4.3501, -5.2037,  0.0000],
#          [ 4.3501,  5.2037,  0.0000],
#          [ 0.0000,  0.0000,  8.2102]]])
# tensor([[0.0000, 0.0000, 0.4315],
#         [0.0000, 0.5000, 0.9315],
#         [0.5000, 0.0000, 0.4699],
#         [0.5000, 0.5000, 0.9699],
#         [0.5000, 0.1963, 0.0966],
#         [0.5000, 0.8037, 0.0966],
#         [0.5000, 0.6963, 0.5966],
#         [0.5000, 0.3037, 0.5966]])
# tensor([[0.0000, 0.0000, 0.4315],
#         [0.0000, 0.5000, 0.9315],
#         [0.5000, 0.0000, 0.4699],
#         [0.5000, 0.5000, 0.9699],
#         [0.5000, 0.1963, 0.0966],
#         [0.5000, 0.8037, 0.0966],
#         [0.5000, 0.6963, 0.5966],
#         [0.5000, 0.3037, 0.5966]])
# perm
# tensor([[[10.4173,  0.0000,  0.0000],
#          [ 0.0000,  9.7060,  0.0000],
#          [ 0.0000,  0.0000,  5.8180]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 1, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.8180,  0.0000,  0.0000],
#          [ 0.0000, 10.4173,  0.0000],
#          [ 0.0000,  0.0000,  9.7060]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 9.7060,  0.0000,  0.0000],
#          [ 0.0000, 10.4173,  0.0000],
#          [ 0.0000,  0.0000,  5.8180]]])
# perm
# tensor([[[ 9.7060,  0.0000,  0.0000],
#          [ 0.0000, 10.4173,  0.0000],
#          [ 0.0000,  0.0000,  5.8180]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.8180,  0.0000,  0.0000],
#          [ 0.0000, 10.4173,  0.0000],
#          [ 0.0000,  0.0000,  9.7060]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 9.7060,  0.0000,  0.0000],
#          [ 0.0000, 10.4173,  0.0000],
#          [ 0.0000,  0.0000,  5.8180]]])
# tensor([[0.3510, 0.3510, 0.0000],
#         [0.0766, 0.0766, 0.5000],
#         [0.7062, 0.3951, 0.5000],
#         [0.3951, 0.7062, 0.5000]])
# tensor([[0.3510, 0.3510, 0.0000],
#         [0.0766, 0.0766, 0.5000],
#         [0.7062, 0.3951, 0.5000],
#         [0.3951, 0.7062, 0.5000]])
# tensor([[[ 4.8530, -5.2087,  0.0000],
#          [ 4.8530,  5.2087,  0.0000],
#          [ 0.0000,  0.0000,  5.8180]]])
# tensor([[[ 4.8530, -5.2087,  0.0000],
#          [ 4.8530,  5.2087,  0.0000],
#          [ 0.0000,  0.0000,  5.8180]]])
# tensor([[0.0000, 0.0000, 0.3510],
#         [0.0000, 0.5000, 0.8510],
#         [0.5000, 0.0000, 0.0766],
#         [0.5000, 0.5000, 0.5766],
#         [0.5000, 0.3444, 0.0506],
#         [0.5000, 0.6556, 0.0506],
#         [0.5000, 0.8444, 0.5506],
#         [0.5000, 0.1556, 0.5506]])
# tensor([[0.0000, 0.0000, 0.3510],
#         [0.0000, 0.5000, 0.8510],
#         [0.5000, 0.0000, 0.0766],
#         [0.5000, 0.5000, 0.5766],
#         [0.5000, 0.3444, 0.0506],
#         [0.5000, 0.6556, 0.0506],
#         [0.5000, 0.8444, 0.5506],
#         [0.5000, 0.1556, 0.5506]])
# perm
# tensor([[[ 9.9268,  0.0000,  0.0000],
#          [ 0.0000, 13.2451,  0.0000],
#          [ 0.0000,  0.0000,  8.3867]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 8.3867,  0.0000,  0.0000],
#          [ 0.0000, 13.2451,  0.0000],
#          [ 0.0000,  0.0000,  9.9268]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 9.9268,  0.0000,  0.0000],
#          [ 0.0000, 13.2451,  0.0000],
#          [ 0.0000,  0.0000,  8.3867]]])
# perm
# tensor([[[ 9.9268,  0.0000,  0.0000],
#          [ 0.0000, 13.2451,  0.0000],
#          [ 0.0000,  0.0000,  8.3867]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 8.3867,  0.0000,  0.0000],
#          [ 0.0000, 13.2451,  0.0000],
#          [ 0.0000,  0.0000,  9.9268]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 9.9268,  0.0000,  0.0000],
#          [ 0.0000, 13.2451,  0.0000],
#          [ 0.0000,  0.0000,  8.3867]]])
# tensor([[0.3230, 0.3230, 0.0000],
#         [0.0180, 0.0180, 0.5000],
#         [0.0830, 0.8922, 0.5000],
#         [0.8922, 0.0830, 0.5000]])
# tensor([[0.3230, 0.3230, 0.0000],
#         [0.0180, 0.0180, 0.5000],
#         [0.0830, 0.8922, 0.5000],
#         [0.8922, 0.0830, 0.5000]])
# tensor([[[ 4.9634, -6.6225,  0.0000],
#          [ 4.9634,  6.6225,  0.0000],
#          [ 0.0000,  0.0000,  8.3867]]])
# tensor([[[ 4.9634, -6.6225,  0.0000],
#          [ 4.9634,  6.6225,  0.0000],
#          [ 0.0000,  0.0000,  8.3867]]])
# tensor([[0.0000, 0.0000, 0.3230],
#         [0.0000, 0.5000, 0.8230],
#         [0.5000, 0.0000, 0.0180],
#         [0.5000, 0.5000, 0.5180],
#         [0.5000, 0.4046, 0.4876],
#         [0.5000, 0.5954, 0.4876],
#         [0.5000, 0.9046, 0.9876],
#         [0.5000, 0.0954, 0.9876]])
# tensor([[0.0000, 0.0000, 0.3230],
#         [0.0000, 0.5000, 0.8230],
#         [0.5000, 0.0000, 0.0180],
#         [0.5000, 0.5000, 0.5180],
#         [0.5000, 0.4046, 0.4876],
#         [0.5000, 0.5954, 0.4876],
#         [0.5000, 0.9046, 0.9876],
#         [0.5000, 0.0954, 0.9876]])
# perm
# tensor([[[ 8.9500,  0.0000,  0.0000],
#          [ 0.0000, 11.3565,  0.0000],
#          [ 0.0000,  0.0000,  5.4228]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.4228,  0.0000,  0.0000],
#          [ 0.0000, 11.3565,  0.0000],
#          [ 0.0000,  0.0000,  8.9500]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.9500,  0.0000,  0.0000],
#          [ 0.0000, 11.3565,  0.0000],
#          [ 0.0000,  0.0000,  5.4228]]])
# perm
# tensor([[[ 8.9500,  0.0000,  0.0000],
#          [ 0.0000, 11.3565,  0.0000],
#          [ 0.0000,  0.0000,  5.4228]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.4228,  0.0000,  0.0000],
#          [ 0.0000, 11.3565,  0.0000],
#          [ 0.0000,  0.0000,  8.9500]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.9500,  0.0000,  0.0000],
#          [ 0.0000, 11.3565,  0.0000],
#          [ 0.0000,  0.0000,  5.4228]]])
# tensor([[0.3187, 0.3187, 0.0000],
#         [0.3655, 0.3655, 0.5000],
#         [0.1789, 0.3331, 0.5000],
#         [0.3331, 0.1789, 0.5000]])
# tensor([[0.3187, 0.3187, 0.0000],
#         [0.3655, 0.3655, 0.5000],
#         [0.1789, 0.3331, 0.5000],
#         [0.3331, 0.1789, 0.5000]])
# tensor([[[ 4.4750, -5.6783,  0.0000],
#          [ 4.4750,  5.6783,  0.0000],
#          [ 0.0000,  0.0000,  5.4228]]])
# tensor([[[ 4.4750, -5.6783,  0.0000],
#          [ 4.4750,  5.6783,  0.0000],
#          [ 0.0000,  0.0000,  5.4228]]])
# tensor([[0.0000, 0.0000, 0.3187],
#         [0.0000, 0.5000, 0.8187],
#         [0.5000, 0.0000, 0.3655],
#         [0.5000, 0.5000, 0.8655],
#         [0.5000, 0.0771, 0.2560],
#         [0.5000, 0.9229, 0.2560],
#         [0.5000, 0.5771, 0.7560],
#         [0.5000, 0.4229, 0.7560]])
# tensor([[0.0000, 0.0000, 0.3187],
#         [0.0000, 0.5000, 0.8187],
#         [0.5000, 0.0000, 0.3655],
#         [0.5000, 0.5000, 0.8655],
#         [0.5000, 0.0771, 0.2560],
#         [0.5000, 0.9229, 0.2560],
#         [0.5000, 0.5771, 0.7560],
#         [0.5000, 0.4229, 0.7560]])
# perm
# tensor([[[ 8.8170,  0.0000,  0.0000],
#          [ 0.0000, 12.9702,  0.0000],
#          [ 0.0000,  0.0000,  6.5346]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.5346,  0.0000,  0.0000],
#          [ 0.0000, 12.9702,  0.0000],
#          [ 0.0000,  0.0000,  8.8170]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.8170,  0.0000,  0.0000],
#          [ 0.0000, 12.9702,  0.0000],
#          [ 0.0000,  0.0000,  6.5346]]])
# perm
# tensor([[[ 8.8170,  0.0000,  0.0000],
#          [ 0.0000, 12.9702,  0.0000],
#          [ 0.0000,  0.0000,  6.5346]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.5346,  0.0000,  0.0000],
#          [ 0.0000, 12.9702,  0.0000],
#          [ 0.0000,  0.0000,  8.8170]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.8170,  0.0000,  0.0000],
#          [ 0.0000, 12.9702,  0.0000],
#          [ 0.0000,  0.0000,  6.5346]]])
# tensor([[0.3499, 0.3499, 0.0000],
#         [0.0665, 0.0665, 0.5000],
#         [0.0072, 0.6925, 0.5000],
#         [0.6925, 0.0072, 0.5000]])
# tensor([[0.3499, 0.3499, 0.0000],
#         [0.0665, 0.0665, 0.5000],
#         [0.0072, 0.6925, 0.5000],
#         [0.6925, 0.0072, 0.5000]])
# tensor([[[ 4.4085, -6.4851,  0.0000],
#          [ 4.4085,  6.4851,  0.0000],
#          [ 0.0000,  0.0000,  6.5346]]])
# tensor([[[ 4.4085, -6.4851,  0.0000],
#          [ 4.4085,  6.4851,  0.0000],
#          [ 0.0000,  0.0000,  6.5346]]])
# tensor([[0.0000, 0.0000, 0.3499],
#         [0.0000, 0.5000, 0.8499],
#         [0.5000, 0.0000, 0.0665],
#         [0.5000, 0.5000, 0.5665],
#         [0.5000, 0.3426, 0.3499],
#         [0.5000, 0.6574, 0.3499],
#         [0.5000, 0.8426, 0.8499],
#         [0.5000, 0.1574, 0.8499]])
# tensor([[0.0000, 0.0000, 0.3499],
#         [0.0000, 0.5000, 0.8499],
#         [0.5000, 0.0000, 0.0665],
#         [0.5000, 0.5000, 0.5665],
#         [0.5000, 0.3426, 0.3499],
#         [0.5000, 0.6574, 0.3499],
#         [0.5000, 0.8426, 0.8499],
#         [0.5000, 0.1574, 0.8499]])
# perm
# tensor([[[10.2210,  0.0000,  0.0000],
#          [ 0.0000,  7.2069,  0.0000],
#          [ 0.0000,  0.0000,  6.6853]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 1, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.6853,  0.0000,  0.0000],
#          [ 0.0000, 10.2210,  0.0000],
#          [ 0.0000,  0.0000,  7.2069]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 7.2069,  0.0000,  0.0000],
#          [ 0.0000, 10.2210,  0.0000],
#          [ 0.0000,  0.0000,  6.6853]]])
# perm
# tensor([[[ 7.2069,  0.0000,  0.0000],
#          [ 0.0000, 10.2210,  0.0000],
#          [ 0.0000,  0.0000,  6.6853]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 6.6853,  0.0000,  0.0000],
#          [ 0.0000, 10.2210,  0.0000],
#          [ 0.0000,  0.0000,  7.2069]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 7.2069,  0.0000,  0.0000],
#          [ 0.0000, 10.2210,  0.0000],
#          [ 0.0000,  0.0000,  6.6853]]])
# tensor([[0.1406, 0.1406, 0.0000],
#         [0.2263, 0.2263, 0.5000],
#         [0.1320, 0.3216, 0.5000],
#         [0.3216, 0.1320, 0.5000]])
# tensor([[0.1406, 0.1406, 0.0000],
#         [0.2263, 0.2263, 0.5000],
#         [0.1320, 0.3216, 0.5000],
#         [0.3216, 0.1320, 0.5000]])
# tensor([[[ 3.6034, -5.1105,  0.0000],
#          [ 3.6034,  5.1105,  0.0000],
#          [ 0.0000,  0.0000,  6.6853]]])
# tensor([[[ 3.6034, -5.1105,  0.0000],
#          [ 3.6034,  5.1105,  0.0000],
#          [ 0.0000,  0.0000,  6.6853]]])
# tensor([[0.0000, 0.0000, 0.1406],
#         [0.0000, 0.5000, 0.6406],
#         [0.5000, 0.0000, 0.2263],
#         [0.5000, 0.5000, 0.7263],
#         [0.5000, 0.0948, 0.2268],
#         [0.5000, 0.9052, 0.2268],
#         [0.5000, 0.5948, 0.7268],
#         [0.5000, 0.4052, 0.7268]])
# tensor([[0.0000, 0.0000, 0.1406],
#         [0.0000, 0.5000, 0.6406],
#         [0.5000, 0.0000, 0.2263],
#         [0.5000, 0.5000, 0.7263],
#         [0.5000, 0.0948, 0.2268],
#         [0.5000, 0.9052, 0.2268],
#         [0.5000, 0.5948, 0.7268],
#         [0.5000, 0.4052, 0.7268]])
# perm
# tensor([[[ 8.9485,  0.0000,  0.0000],
#          [ 0.0000, 11.2335,  0.0000],
#          [ 0.0000,  0.0000,  8.7005]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 8.7005,  0.0000,  0.0000],
#          [ 0.0000, 11.2335,  0.0000],
#          [ 0.0000,  0.0000,  8.9485]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.9485,  0.0000,  0.0000],
#          [ 0.0000, 11.2335,  0.0000],
#          [ 0.0000,  0.0000,  8.7005]]])
# perm
# tensor([[[ 8.9485,  0.0000,  0.0000],
#          [ 0.0000, 11.2335,  0.0000],
#          [ 0.0000,  0.0000,  8.7005]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 8.7005,  0.0000,  0.0000],
#          [ 0.0000, 11.2335,  0.0000],
#          [ 0.0000,  0.0000,  8.9485]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.9485,  0.0000,  0.0000],
#          [ 0.0000, 11.2335,  0.0000],
#          [ 0.0000,  0.0000,  8.7005]]])
# tensor([[0.1029, 0.1029, 0.0000],
#         [0.1996, 0.1996, 0.5000],
#         [0.2850, 0.3577, 0.5000],
#         [0.3577, 0.2850, 0.5000]])
# tensor([[0.1029, 0.1029, 0.0000],
#         [0.1996, 0.1996, 0.5000],
#         [0.2850, 0.3577, 0.5000],
#         [0.3577, 0.2850, 0.5000]])
# tensor([[[ 4.4742, -5.6167,  0.0000],
#          [ 4.4742,  5.6167,  0.0000],
#          [ 0.0000,  0.0000,  8.7005]]])
# tensor([[[ 4.4742, -5.6167,  0.0000],
#          [ 4.4742,  5.6167,  0.0000],
#          [ 0.0000,  0.0000,  8.7005]]])
# tensor([[0.0000, 0.0000, 0.1029],
#         [0.0000, 0.5000, 0.6029],
#         [0.5000, 0.0000, 0.1996],
#         [0.5000, 0.5000, 0.6996],
#         [0.5000, 0.0363, 0.3213],
#         [0.5000, 0.9637, 0.3213],
#         [0.5000, 0.5363, 0.8213],
# ...
# tensor([[0.0000, 0.0000, 0.3810],
#         [0.0000, 0.5000, 0.8810],
#         [0.5000, 0.0000, 0.1981],
#         [0.5000, 0.5000, 0.6981],
#         [0.5000, 0.0943, 0.0619],
#         [0.5000, 0.9057, 0.0619],
#         [0.5000, 0.5943, 0.5619],
#         [0.5000, 0.4057, 0.5619]])
# tensor([[0.0000, 0.0000, 0.3810],
#         [0.0000, 0.5000, 0.8810],
#         [0.5000, 0.0000, 0.1981],
#         [0.5000, 0.5000, 0.6981],
#         [0.5000, 0.0943, 0.0619],
#         [0.5000, 0.9057, 0.0619],
#         [0.5000, 0.5943, 0.5619],
#         [0.5000, 0.4057, 0.5619]])
# perm
# tensor([[[12.7663,  0.0000,  0.0000],
#          [ 0.0000,  9.2484,  0.0000],
#          [ 0.0000,  0.0000,  7.3240]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 1, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.3240,  0.0000,  0.0000],
#          [ 0.0000, 12.7663,  0.0000],
#          [ 0.0000,  0.0000,  9.2484]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 9.2484,  0.0000,  0.0000],
#          [ 0.0000, 12.7663,  0.0000],
#          [ 0.0000,  0.0000,  7.3240]]])
# perm
# tensor([[[ 9.2484,  0.0000,  0.0000],
#          [ 0.0000, 12.7663,  0.0000],
#          [ 0.0000,  0.0000,  7.3240]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.3240,  0.0000,  0.0000],
#          [ 0.0000, 12.7663,  0.0000],
#          [ 0.0000,  0.0000,  9.2484]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 9.2484,  0.0000,  0.0000],
#          [ 0.0000, 12.7663,  0.0000],
#          [ 0.0000,  0.0000,  7.3240]]])
# tensor([[0.1895, 0.1895, 0.0000],
#         [0.1490, 0.1490, 0.5000],
#         [0.9938, 0.1761, 0.5000],
#         [0.1761, 0.9938, 0.5000]])
# tensor([[0.1895, 0.1895, 0.0000],
#         [0.1490, 0.1490, 0.5000],
#         [0.9938, 0.1761, 0.5000],
#         [0.1761, 0.9938, 0.5000]])
# tensor([[[ 4.6242, -6.3831,  0.0000],
#          [ 4.6242,  6.3831,  0.0000],
#          [ 0.0000,  0.0000,  7.3240]]])
# tensor([[[ 4.6242, -6.3831,  0.0000],
#          [ 4.6242,  6.3831,  0.0000],
#          [ 0.0000,  0.0000,  7.3240]]])
# tensor([[0.0000, 0.0000, 0.1895],
#         [0.0000, 0.5000, 0.6895],
#         [0.5000, 0.0000, 0.1490],
#         [0.5000, 0.5000, 0.6490],
#         [0.5000, 0.0912, 0.0850],
#         [0.5000, 0.9088, 0.0850],
#         [0.5000, 0.5912, 0.5850],
#         [0.5000, 0.4088, 0.5850]])
# tensor([[0.0000, 0.0000, 0.1895],
#         [0.0000, 0.5000, 0.6895],
#         [0.5000, 0.0000, 0.1490],
#         [0.5000, 0.5000, 0.6490],
#         [0.5000, 0.0912, 0.0850],
#         [0.5000, 0.9088, 0.0850],
#         [0.5000, 0.5912, 0.5850],
#         [0.5000, 0.4088, 0.5850]])
# perm
# tensor([[[7.9336, 0.0000, 0.0000],
#          [0.0000, 9.9376, 0.0000],
#          [0.0000, 0.0000, 5.7472]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[5.7472, 0.0000, 0.0000],
#          [0.0000, 9.9376, 0.0000],
#          [0.0000, 0.0000, 7.9336]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.9336, 0.0000, 0.0000],
#          [0.0000, 9.9376, 0.0000],
#          [0.0000, 0.0000, 5.7472]]])
# perm
# tensor([[[7.9336, 0.0000, 0.0000],
#          [0.0000, 9.9376, 0.0000],
#          [0.0000, 0.0000, 5.7472]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[5.7472, 0.0000, 0.0000],
#          [0.0000, 9.9376, 0.0000],
#          [0.0000, 0.0000, 7.9336]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[7.9336, 0.0000, 0.0000],
#          [0.0000, 9.9376, 0.0000],
#          [0.0000, 0.0000, 5.7472]]])
# tensor([[0.1698, 0.1698, 0.0000],
#         [0.0291, 0.0291, 0.5000],
#         [0.6754, 0.5516, 0.5000],
#         [0.5516, 0.6754, 0.5000]])
# tensor([[0.1698, 0.1698, 0.0000],
#         [0.0291, 0.0291, 0.5000],
#         [0.6754, 0.5516, 0.5000],
#         [0.5516, 0.6754, 0.5000]])
# tensor([[[ 3.9668, -4.9688,  0.0000],
#          [ 3.9668,  4.9688,  0.0000],
#          [ 0.0000,  0.0000,  5.7472]]])
# tensor([[[ 3.9668, -4.9688,  0.0000],
#          [ 3.9668,  4.9688,  0.0000],
#          [ 0.0000,  0.0000,  5.7472]]])
# tensor([[0.0000, 0.0000, 0.1698],
#         [0.0000, 0.5000, 0.6698],
#         [0.5000, 0.0000, 0.0291],
#         [0.5000, 0.5000, 0.5291],
#         [0.5000, 0.4381, 0.1135],
#         [0.5000, 0.5619, 0.1135],
#         [0.5000, 0.9381, 0.6135],
#         [0.5000, 0.0619, 0.6135]])
# tensor([[0.0000, 0.0000, 0.1698],
#         [0.0000, 0.5000, 0.6698],
#         [0.5000, 0.0000, 0.0291],
#         [0.5000, 0.5000, 0.5291],
#         [0.5000, 0.4381, 0.1135],
#         [0.5000, 0.5619, 0.1135],
#         [0.5000, 0.9381, 0.6135],
#         [0.5000, 0.0619, 0.6135]])
# perm
# tensor([[[11.0129,  0.0000,  0.0000],
#          [ 0.0000,  8.5120,  0.0000],
#          [ 0.0000,  0.0000,  8.7517]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 2, 1]])
# perm_conv_lat_proj
# tensor([[[ 8.7517,  0.0000,  0.0000],
#          [ 0.0000, 11.0129,  0.0000],
#          [ 0.0000,  0.0000,  8.5120]]])
# tensor([[1, 0, 2]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.5120,  0.0000,  0.0000],
#          [ 0.0000, 11.0129,  0.0000],
#          [ 0.0000,  0.0000,  8.7517]]])
# perm
# tensor([[[ 8.5120,  0.0000,  0.0000],
#          [ 0.0000, 11.0129,  0.0000],
#          [ 0.0000,  0.0000,  8.7517]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 2, 0]])
# perm_conv_lat_proj
# tensor([[[ 8.7517,  0.0000,  0.0000],
#          [ 0.0000, 11.0129,  0.0000],
#          [ 0.0000,  0.0000,  8.5120]]])
# tensor([[1, 0, 2]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.5120,  0.0000,  0.0000],
#          [ 0.0000, 11.0129,  0.0000],
#          [ 0.0000,  0.0000,  8.7517]]])
# tensor([[0.2155, 0.2155, 0.0000],
#         [0.2161, 0.2161, 0.5000],
#         [0.5194, 0.4849, 0.5000],
#         [0.4849, 0.5194, 0.5000]])
# tensor([[0.2155, 0.2155, 0.0000],
#         [0.2161, 0.2161, 0.5000],
#         [0.5194, 0.4849, 0.5000],
#         [0.4849, 0.5194, 0.5000]])
# tensor([[[ 4.2560, -5.5064,  0.0000],
#          [ 4.2560,  5.5064,  0.0000],
#          [ 0.0000,  0.0000,  8.7517]]])
# tensor([[[ 4.2560, -5.5064,  0.0000],
#          [ 4.2560,  5.5064,  0.0000],
#          [ 0.0000,  0.0000,  8.7517]]])
# tensor([[0.0000, 0.0000, 0.2155],
#         [0.0000, 0.5000, 0.7155],
#         [0.5000, 0.0000, 0.2161],
#         [0.5000, 0.5000, 0.7161],
#         [0.5000, 0.4828, 0.0022],
#         [0.5000, 0.5172, 0.0022],
#         [0.5000, 0.9828, 0.5022],
#         [0.5000, 0.0172, 0.5022]])
# tensor([[0.0000, 0.0000, 0.2155],
#         [0.0000, 0.5000, 0.7155],
#         [0.5000, 0.0000, 0.2161],
#         [0.5000, 0.5000, 0.7161],
#         [0.5000, 0.4828, 0.0022],
#         [0.5000, 0.5172, 0.0022],
#         [0.5000, 0.9828, 0.5022],
#         [0.5000, 0.0172, 0.5022]])
# perm
# tensor([[[10.4478,  0.0000,  0.0000],
#          [ 0.0000, 10.8486,  0.0000],
#          [ 0.0000,  0.0000,  5.3144]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.3144,  0.0000,  0.0000],
#          [ 0.0000, 10.8486,  0.0000],
#          [ 0.0000,  0.0000, 10.4478]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.4478,  0.0000,  0.0000],
#          [ 0.0000, 10.8486,  0.0000],
#          [ 0.0000,  0.0000,  5.3144]]])
# perm
# tensor([[[10.4478,  0.0000,  0.0000],
#          [ 0.0000, 10.8486,  0.0000],
#          [ 0.0000,  0.0000,  5.3144]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.3144,  0.0000,  0.0000],
#          [ 0.0000, 10.8486,  0.0000],
#          [ 0.0000,  0.0000, 10.4478]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.4478,  0.0000,  0.0000],
#          [ 0.0000, 10.8486,  0.0000],
#          [ 0.0000,  0.0000,  5.3144]]])
# tensor([[0.2647, 0.2647, 0.0000],
#         [0.1786, 0.1786, 0.5000],
#         [0.0759, 0.4709, 0.5000],
#         [0.4709, 0.0759, 0.5000]])
# tensor([[0.2647, 0.2647, 0.0000],
#         [0.1786, 0.1786, 0.5000],
#         [0.0759, 0.4709, 0.5000],
#         [0.4709, 0.0759, 0.5000]])
# tensor([[[ 5.2239, -5.4243,  0.0000],
#          [ 5.2239,  5.4243,  0.0000],
#          [ 0.0000,  0.0000,  5.3144]]])
# tensor([[[ 5.2239, -5.4243,  0.0000],
#          [ 5.2239,  5.4243,  0.0000],
#          [ 0.0000,  0.0000,  5.3144]]])
# tensor([[0.0000, 0.0000, 0.2647],
#         [0.0000, 0.5000, 0.7647],
#         [0.5000, 0.0000, 0.1786],
#         [0.5000, 0.5000, 0.6786],
#         [0.5000, 0.1975, 0.2734],
#         [0.5000, 0.8025, 0.2734],
#         [0.5000, 0.6975, 0.7734],
#         [0.5000, 0.3025, 0.7734]])
# tensor([[0.0000, 0.0000, 0.2647],
#         [0.0000, 0.5000, 0.7647],
#         [0.5000, 0.0000, 0.1786],
#         [0.5000, 0.5000, 0.6786],
#         [0.5000, 0.1975, 0.2734],
#         [0.5000, 0.8025, 0.2734],
#         [0.5000, 0.6975, 0.7734],
#         [0.5000, 0.3025, 0.7734]])
# perm
# tensor([[[10.0476,  0.0000,  0.0000],
#          [ 0.0000, 14.1194,  0.0000],
#          [ 0.0000,  0.0000,  5.7316]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.7316,  0.0000,  0.0000],
#          [ 0.0000, 14.1194,  0.0000],
#          [ 0.0000,  0.0000, 10.0476]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.0476,  0.0000,  0.0000],
#          [ 0.0000, 14.1194,  0.0000],
#          [ 0.0000,  0.0000,  5.7316]]])
# perm
# tensor([[[10.0476,  0.0000,  0.0000],
#          [ 0.0000, 14.1194,  0.0000],
#          [ 0.0000,  0.0000,  5.7316]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 5.7316,  0.0000,  0.0000],
#          [ 0.0000, 14.1194,  0.0000],
#          [ 0.0000,  0.0000, 10.0476]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.0476,  0.0000,  0.0000],
#          [ 0.0000, 14.1194,  0.0000],
#          [ 0.0000,  0.0000,  5.7316]]])
# tensor([[0.4672, 0.4672, 0.0000],
#         [0.2642, 0.2642, 0.5000],
#         [0.8342, 0.2776, 0.5000],
#         [0.2776, 0.8342, 0.5000]])
# tensor([[0.4672, 0.4672, 0.0000],
#         [0.2642, 0.2642, 0.5000],
#         [0.8342, 0.2776, 0.5000],
#         [0.2776, 0.8342, 0.5000]])
# tensor([[[ 5.0238, -7.0597,  0.0000],
#          [ 5.0238,  7.0597,  0.0000],
#          [ 0.0000,  0.0000,  5.7316]]])
# tensor([[[ 5.0238, -7.0597,  0.0000],
#          [ 5.0238,  7.0597,  0.0000],
#          [ 0.0000,  0.0000,  5.7316]]])
# tensor([[0.0000, 0.0000, 0.4672],
#         [0.0000, 0.5000, 0.9672],
#         [0.5000, 0.0000, 0.2642],
#         [0.5000, 0.5000, 0.7642],
#         [0.5000, 0.2217, 0.0559],
#         [0.5000, 0.7783, 0.0559],
#         [0.5000, 0.7217, 0.5559],
#         [0.5000, 0.2783, 0.5559]])
# tensor([[0.0000, 0.0000, 0.4672],
#         [0.0000, 0.5000, 0.9672],
#         [0.5000, 0.0000, 0.2642],
#         [0.5000, 0.5000, 0.7642],
#         [0.5000, 0.2217, 0.0559],
#         [0.5000, 0.7783, 0.0559],
#         [0.5000, 0.7217, 0.5559],
#         [0.5000, 0.2783, 0.5559]])
# perm
# tensor([[[ 8.5523,  0.0000,  0.0000],
#          [ 0.0000, 12.3017,  0.0000],
#          [ 0.0000,  0.0000,  7.2764]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.2764,  0.0000,  0.0000],
#          [ 0.0000, 12.3017,  0.0000],
#          [ 0.0000,  0.0000,  8.5523]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.5523,  0.0000,  0.0000],
#          [ 0.0000, 12.3017,  0.0000],
#          [ 0.0000,  0.0000,  7.2764]]])
# perm
# tensor([[[ 8.5523,  0.0000,  0.0000],
#          [ 0.0000, 12.3017,  0.0000],
#          [ 0.0000,  0.0000,  7.2764]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.2764,  0.0000,  0.0000],
#          [ 0.0000, 12.3017,  0.0000],
#          [ 0.0000,  0.0000,  8.5523]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[ 8.5523,  0.0000,  0.0000],
#          [ 0.0000, 12.3017,  0.0000],
#          [ 0.0000,  0.0000,  7.2764]]])
# tensor([[0.3554, 0.3554, 0.0000],
#         [0.0362, 0.0362, 0.5000],
#         [0.6092, 0.4818, 0.5000],
#         [0.4818, 0.6092, 0.5000]])
# tensor([[0.3554, 0.3554, 0.0000],
#         [0.0362, 0.0362, 0.5000],
#         [0.6092, 0.4818, 0.5000],
#         [0.4818, 0.6092, 0.5000]])
# tensor([[[ 4.2761, -6.1509,  0.0000],
#          [ 4.2761,  6.1509,  0.0000],
#          [ 0.0000,  0.0000,  7.2764]]])
# tensor([[[ 4.2761, -6.1509,  0.0000],
#          [ 4.2761,  6.1509,  0.0000],
#          [ 0.0000,  0.0000,  7.2764]]])
# tensor([[0.0000, 0.0000, 0.3554],
#         [0.0000, 0.5000, 0.8554],
#         [0.5000, 0.0000, 0.0362],
#         [0.5000, 0.5000, 0.5362],
#         [0.5000, 0.4363, 0.0455],
#         [0.5000, 0.5637, 0.0455],
#         [0.5000, 0.9363, 0.5455],
#         [0.5000, 0.0637, 0.5455]])
# tensor([[0.0000, 0.0000, 0.3554],
#         [0.0000, 0.5000, 0.8554],
#         [0.5000, 0.0000, 0.0362],
#         [0.5000, 0.5000, 0.5362],
#         [0.5000, 0.4363, 0.0455],
#         [0.5000, 0.5637, 0.0455],
#         [0.5000, 0.9363, 0.5455],
#         [0.5000, 0.0637, 0.5455]])
# perm
# tensor([[[12.7752,  0.0000,  0.0000],
#          [ 0.0000, 10.3144,  0.0000],
#          [ 0.0000,  0.0000,  7.1697]]])
# tensor([[[0., 0., 1.],
#          [1., 0., 0.],
#          [0., 1., 0.]]])
# tensor([[0, 1, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.1697,  0.0000,  0.0000],
#          [ 0.0000, 12.7752,  0.0000],
#          [ 0.0000,  0.0000, 10.3144]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.3144,  0.0000,  0.0000],
#          [ 0.0000, 12.7752,  0.0000],
#          [ 0.0000,  0.0000,  7.1697]]])
# perm
# tensor([[[10.3144,  0.0000,  0.0000],
#          [ 0.0000, 12.7752,  0.0000],
#          [ 0.0000,  0.0000,  7.1697]]])
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# tensor([[1, 0, 2]])
# perm_conv_lat_proj
# tensor([[[ 7.1697,  0.0000,  0.0000],
#          [ 0.0000, 12.7752,  0.0000],
#          [ 0.0000,  0.0000, 10.3144]]])
# tensor([[1, 2, 0]])
# permA
# tensor([[[0., 0., 1.],
#          [0., 1., 0.],
#          [1., 0., 0.]]])
# permA_conv_lat_proj
# tensor([[[10.3144,  0.0000,  0.0000],
#          [ 0.0000, 12.7752,  0.0000],
#          [ 0.0000,  0.0000,  7.1697]]])
# tensor([[0.0010, 0.0010, 0.0000],
#         [0.4836, 0.4836, 0.5000],
#         [0.7939, 0.5743, 0.5000],
#         [0.5743, 0.7939, 0.5000]])
# tensor([[0.0010, 0.0010, 0.0000],
#         [0.4836, 0.4836, 0.5000],
#         [0.7939, 0.5743, 0.5000],
#         [0.5743, 0.7939, 0.5000]])
# tensor([[[ 5.1572, -6.3876,  0.0000],
#          [ 5.1572,  6.3876,  0.0000],
#          [ 0.0000,  0.0000,  7.1697]]])
# tensor([[[ 5.1572, -6.3876,  0.0000],
#          [ 5.1572,  6.3876,  0.0000],
#          [ 0.0000,  0.0000,  7.1697]]])
# tensor([[0.0000, 0.0000, 0.0010],
#         [0.0000, 0.5000, 0.5010],
#         [0.5000, 0.0000, 0.4836],
#         [0.5000, 0.5000, 0.9836],
#         [0.5000, 0.3902, 0.1841],
#         [0.5000, 0.6098, 0.1841],
#         [0.5000, 0.8902, 0.6841],
#         [0.5000, 0.1098, 0.6841]])
# tensor([[0.0000, 0.0000, 0.0010],
#         [0.0000, 0.5000, 0.5010],
#         [0.5000, 0.0000, 0.4836],
#         [0.5000, 0.5000, 0.9836],
#         [0.5000, 0.3902, 0.1841],
#         [0.5000, 0.6098, 0.1841],
#         [0.5000, 0.8902, 0.6841],
#         [0.5000, 0.1098, 0.6841]])

# %%
res = []
success = []
failed = []
error = []
consistency = []
inconsistency_data = {
}

torch.set_num_threads(24)
for idx, data in tqdm(enumerate(dataset)):
    data_batch = collate([data])
    _success = False
    for i in range(3):
        if not _success:
            coords, lattice, pos_frac_proj, conv_lat_proj = _project_to_space_group(data_batch)
            structure = Structure(lattice=lattice, coords=coords, species=data_batch.species)
            try:
                spga = SpacegroupAnalyzer(structure)
            except:
                print(f"Idx: {idx} failed, spg {data.space_groups}")
                continue
            _success = True
    if not _success:
        error.append(idx)
        failed.append(idx)
        continue
    
    coords2, lattice2, pos_frac_proj2, conv_lat_proj2 = _project_to_space_group(data_batch, coords, lattice)
    # coords2, lattice2, pos_frac_proj2, conv_lat_proj2 = _project_to_space_group(data_batch, coords2, lattice2)
    if torch.allclose(coords, coords2, atol=1e-3):
        consistency.append(idx)
    else:
        print(f"Idx: {idx} failed, spg {data.space_groups} inconsistent")    
        inconsistency_data[idx]={
            "data": data,
            "coords": coords,
            "coords2": coords2,
            "lattice": lattice,
            "lattice2": lattice2,
            "pos_frac_proj": pos_frac_proj,
            "pos_frac_proj2": pos_frac_proj2,
            "conv_lat_proj": conv_lat_proj,
            "conv_lat_proj2": conv_lat_proj2,
        }
    sgn = spga.get_space_group_number()
    res.append(sgn)
    if sgn == data.space_groups.item():
        success.append(idx)
    else:
        failed.append(idx)
        print(f"Idx: {idx} failed, spg {data.space_groups} != {sgn}")
print("Len of success: ", len(success))
print("Len of failed: ", len(failed))
print("Len of error: ", len(error))
print("Len of consistency: ", len(consistency))
# Out:
# 0it [00:00, ?it/s]
# Idx: 0 failed, spg 39 inconsistent
# Idx: 1 failed, spg 39 inconsistent
# Idx: 2 failed, spg 39 inconsistent
# Idx: 3 failed, spg 39 inconsistent
# Idx: 4 failed, spg 39 inconsistent
# Idx: 5 failed, spg 39 inconsistent
# Idx: 6 failed, spg 39 inconsistent
# Idx: 8 failed, spg 39 inconsistent
# Idx: 10 failed, spg 39 inconsistent
# Idx: 12 failed, spg 39 inconsistent
# Idx: 13 failed, spg 39 inconsistent
# Idx: 15 failed, spg 39 inconsistent
# Idx: 18 failed, spg 39 inconsistent
# Idx: 21 failed, spg 39 inconsistent
# Idx: 22 failed, spg 39 inconsistent
# Idx: 24 failed, spg 39 inconsistent
# Idx: 26 failed, spg 39 inconsistent
# Idx: 27 failed, spg 39 inconsistent
# Idx: 28 failed, spg 39 inconsistent
# Idx: 29 failed, spg 39 inconsistent
# Idx: 30 failed, spg 39 inconsistent
# Idx: 31 failed, spg 39 inconsistent
# Idx: 34 failed, spg 39 inconsistent
# Idx: 35 failed, spg 39 inconsistent
# Idx: 36 failed, spg 39 inconsistent
# Idx: 38 failed, spg 39 inconsistent
# Idx: 39 failed, spg 39 inconsistent
# Idx: 41 failed, spg 39 inconsistent
# Idx: 45 failed, spg 39 inconsistent
# Idx: 46 failed, spg 39 inconsistent
# Idx: 50 failed, spg 39 inconsistent
# Idx: 51 failed, spg 39 inconsistent
# Idx: 52 failed, spg 39 inconsistent
# Idx: 53 failed, spg 39 inconsistent
# Idx: 54 failed, spg 39 inconsistent
# Idx: 55 failed, spg 39 inconsistent
# Idx: 56 failed, spg 39 inconsistent
# Idx: 59 failed, spg 39 inconsistent
# Idx: 60 failed, spg 39 inconsistent
# Idx: 61 failed, spg 39 inconsistent
# Idx: 65 failed, spg 39 inconsistent
# Idx: 66 failed, spg 39 inconsistent
# Idx: 67 failed, spg 39 inconsistent
# Idx: 68 failed, spg 39 inconsistent
# Idx: 69 failed, spg 39 inconsistent
# Idx: 71 failed, spg 39 inconsistent
# Idx: 72 failed, spg 39 inconsistent
# Idx: 74 failed, spg 39 inconsistent
# Idx: 75 failed, spg 39 inconsistent
# Idx: 76 failed, spg 39 inconsistent
# Idx: 78 failed, spg 39 inconsistent
# Idx: 79 failed, spg 39 inconsistent
# Idx: 81 failed, spg 39 inconsistent
# Idx: 82 failed, spg 39 inconsistent
# Idx: 85 failed, spg 39 inconsistent
# Idx: 86 failed, spg 39 inconsistent
# Idx: 88 failed, spg 39 inconsistent
# Idx: 92 failed, spg 39 inconsistent
# Idx: 94 failed, spg 39 inconsistent
# Idx: 96 failed, spg 39
# Idx: 100 failed, spg 39
# Idx: 100 failed, spg 39 inconsistent
# Idx: 101 failed, spg 39 inconsistent
# Idx: 102 failed, spg 39 inconsistent
# Idx: 103 failed, spg 39 inconsistent
# Idx: 105 failed, spg 39 inconsistent
# Idx: 107 failed, spg 39 inconsistent
# Idx: 109 failed, spg 39 inconsistent
# Idx: 110 failed, spg 39 inconsistent
# Idx: 111 failed, spg 39 inconsistent
# Idx: 113 failed, spg 39 inconsistent
# Idx: 114 failed, spg 39 inconsistent
# Idx: 115 failed, spg 39 inconsistent
# Idx: 117 failed, spg 39 inconsistent
# Idx: 118 failed, spg 39 inconsistent
# Idx: 120 failed, spg 39 inconsistent
# Idx: 121 failed, spg 39 inconsistent
# Idx: 123 failed, spg 39 inconsistent
# Idx: 124 failed, spg 39 inconsistent
# Idx: 126 failed, spg 39 inconsistent
# Idx: 127 failed, spg 39 inconsistent
# Idx: 128 failed, spg 39 inconsistent
# Idx: 129 failed, spg 39 inconsistent
# Idx: 132 failed, spg 39 inconsistent
# Idx: 133 failed, spg 39 inconsistent
# Idx: 136 failed, spg 39 inconsistent
# Idx: 137 failed, spg 39 inconsistent
# Idx: 138 failed, spg 39 inconsistent
# Idx: 139 failed, spg 39 inconsistent
# Idx: 140 failed, spg 39 inconsistent
# Idx: 142 failed, spg 39 inconsistent
# Idx: 143 failed, spg 39 inconsistent
# Idx: 144 failed, spg 39 inconsistent
# Idx: 145 failed, spg 39 inconsistent
# Idx: 148 failed, spg 39 inconsistent
# Idx: 149 failed, spg 39 inconsistent
# Idx: 150 failed, spg 39 inconsistent
# Idx: 151 failed, spg 39 inconsistent
# Idx: 153 failed, spg 39 inconsistent
# Idx: 154 failed, spg 39 inconsistent
# Idx: 155 failed, spg 39 inconsistent
# Idx: 157 failed, spg 39 inconsistent
# Idx: 158 failed, spg 39 inconsistent
# Idx: 159 failed, spg 39 inconsistent
# Idx: 160 failed, spg 39 inconsistent
# Idx: 161 failed, spg 39 inconsistent
# Idx: 164 failed, spg 39 inconsistent
# Idx: 166 failed, spg 39 inconsistent
# Idx: 167 failed, spg 39 inconsistent
# Idx: 168 failed, spg 39 inconsistent
# Idx: 171 failed, spg 39 inconsistent
# Idx: 172 failed, spg 39 inconsistent
# Idx: 173 failed, spg 39 inconsistent
# Idx: 175 failed, spg 39 inconsistent
# Idx: 176 failed, spg 39 inconsistent
# Idx: 181 failed, spg 39 inconsistent
# Idx: 182 failed, spg 39 inconsistent
# Idx: 183 failed, spg 39 inconsistent
# Idx: 186 failed, spg 39 inconsistent
# Idx: 187 failed, spg 39 inconsistent
# Idx: 188 failed, spg 39 inconsistent
# Idx: 189 failed, spg 39 inconsistent
# Idx: 190 failed, spg 39 inconsistent
# Idx: 191 failed, spg 39
# Idx: 191 failed, spg 39 inconsistent
# Idx: 193 failed, spg 39 inconsistent
# Idx: 194 failed, spg 39 inconsistent
# Idx: 195 failed, spg 39 inconsistent
# Idx: 199 failed, spg 39 inconsistent
# Idx: 202 failed, spg 39 inconsistent
# Idx: 203 failed, spg 39 inconsistent
# Idx: 204 failed, spg 39 inconsistent
# Idx: 205 failed, spg 39 inconsistent
# Idx: 206 failed, spg 39 inconsistent
# Idx: 207 failed, spg 39 inconsistent
# Idx: 209 failed, spg 39 inconsistent
# Idx: 210 failed, spg 39 inconsistent
# Idx: 211 failed, spg 39 inconsistent
# Idx: 213 failed, spg 39 inconsistent
# Idx: 214 failed, spg 39 inconsistent
# Idx: 215 failed, spg 39 inconsistent
# Idx: 216 failed, spg 39 inconsistent
# Idx: 217 failed, spg 39 inconsistent
# Idx: 219 failed, spg 39 inconsistent
# Idx: 220 failed, spg 39 inconsistent
# Idx: 222 failed, spg 39 inconsistent
# Idx: 224 failed, spg 39 inconsistent
# Idx: 225 failed, spg 39 inconsistent
# Idx: 226 failed, spg 39 inconsistent
# Idx: 227 failed, spg 39 inconsistent
# Idx: 228 failed, spg 39 inconsistent
# Idx: 229 failed, spg 39 inconsistent
# Idx: 230 failed, spg 39 inconsistent
# Idx: 231 failed, spg 39 inconsistent
# Idx: 232 failed, spg 39 inconsistent
# Idx: 233 failed, spg 39 inconsistent
# Idx: 234 failed, spg 39 inconsistent
# Idx: 235 failed, spg 39 inconsistent
# Idx: 236 failed, spg 39 inconsistent
# Idx: 237 failed, spg 39 inconsistent
# Idx: 238 failed, spg 39 inconsistent
# Idx: 239 failed, spg 39 inconsistent
# Idx: 240 failed, spg 39 inconsistent
# Idx: 243 failed, spg 39 inconsistent
# Idx: 244 failed, spg 39 inconsistent
# Idx: 245 failed, spg 39 inconsistent
# Idx: 246 failed, spg 39 inconsistent
# Idx: 247 failed, spg 39 inconsistent
# Idx: 248 failed, spg 39 inconsistent
# Idx: 250 failed, spg 39 inconsistent
# Idx: 251 failed, spg 39 inconsistent
# Idx: 252 failed, spg 39 inconsistent
# Idx: 253 failed, spg 39 inconsistent
# Idx: 255 failed, spg 39 inconsistent
# Idx: 259 failed, spg 39 inconsistent
# Idx: 261 failed, spg 39 inconsistent
# Idx: 262 failed, spg 39 inconsistent
# Idx: 263 failed, spg 39 inconsistent
# Idx: 264 failed, spg 39 inconsistent
# Idx: 265 failed, spg 39 inconsistent
# Idx: 266 failed, spg 39 inconsistent
# Idx: 267 failed, spg 39 inconsistent
# Idx: 268 failed, spg 39 inconsistent
# Idx: 269 failed, spg 39 inconsistent
# Idx: 270 failed, spg 39 inconsistent
# Idx: 272 failed, spg 39 inconsistent
# Idx: 273 failed, spg 39 inconsistent
# Idx: 275 failed, spg 39 inconsistent
# Idx: 276 failed, spg 39 inconsistent
# Idx: 277 failed, spg 39 inconsistent
# Idx: 279 failed, spg 39 inconsistent
# Idx: 280 failed, spg 39 inconsistent
# Idx: 281 failed, spg 39 inconsistent
# Idx: 282 failed, spg 39 inconsistent
# Idx: 285 failed, spg 39 inconsistent
# Idx: 286 failed, spg 39 inconsistent
# Idx: 287 failed, spg 39 inconsistent
# Idx: 288 failed, spg 39 inconsistent
# Idx: 289 failed, spg 39 inconsistent
# Idx: 290 failed, spg 39 inconsistent
# Idx: 293 failed, spg 39 inconsistent
# Idx: 294 failed, spg 39 inconsistent
# Idx: 295 failed, spg 39 inconsistent
# Idx: 296 failed, spg 39 inconsistent
# Idx: 300 failed, spg 39 inconsistent
# Idx: 302 failed, spg 39 inconsistent
# Idx: 303 failed, spg 39 inconsistent
# Idx: 304 failed, spg 39 inconsistent
# Idx: 305 failed, spg 39 inconsistent
# Idx: 307 failed, spg 39 inconsistent
# Idx: 308 failed, spg 39 inconsistent
# Idx: 309 failed, spg 39 inconsistent
# Idx: 310 failed, spg 39 inconsistent
# Idx: 311 failed, spg 39 inconsistent
# Idx: 312 failed, spg 39 inconsistent
# Idx: 313 failed, spg 39 inconsistent
# Idx: 314 failed, spg 39 inconsistent
# Idx: 315 failed, spg 39 inconsistent
# Idx: 320 failed, spg 39 inconsistent
# Idx: 321 failed, spg 39 inconsistent
# Idx: 322 failed, spg 39 inconsistent
# Idx: 324 failed, spg 39 inconsistent
# Idx: 325 failed, spg 39 inconsistent
# Idx: 326 failed, spg 39 inconsistent
# Idx: 328 failed, spg 39 inconsistent
# Idx: 329 failed, spg 39 inconsistent
# Idx: 330 failed, spg 39 inconsistent
# Idx: 331 failed, spg 39 inconsistent
# Idx: 333 failed, spg 39 inconsistent
# Idx: 335 failed, spg 39 inconsistent
# Idx: 336 failed, spg 39 inconsistent
# Idx: 337 failed, spg 39 inconsistent
# Idx: 338 failed, spg 39 inconsistent
# Idx: 341 failed, spg 39 inconsistent
# Idx: 343 failed, spg 39 inconsistent
# Idx: 346 failed, spg 39 inconsistent
# Idx: 347 failed, spg 39 inconsistent
# Idx: 348 failed, spg 39 inconsistent
# Idx: 349 failed, spg 39 inconsistent
# Idx: 351 failed, spg 39 inconsistent
# Idx: 354 failed, spg 39 inconsistent
# Idx: 355 failed, spg 39 inconsistent
# Idx: 356 failed, spg 39 inconsistent
# Idx: 357 failed, spg 39 inconsistent
# Idx: 358 failed, spg 39 inconsistent
# Idx: 359 failed, spg 39 inconsistent
# Idx: 360 failed, spg 39 inconsistent
# Idx: 361 failed, spg 39 inconsistent
# Idx: 363 failed, spg 39 inconsistent
# Idx: 365 failed, spg 39 inconsistent
# Idx: 366 failed, spg 39 inconsistent
# Idx: 368 failed, spg 39 inconsistent
# Idx: 370 failed, spg 39 inconsistent
# Idx: 371 failed, spg 39 inconsistent
# Idx: 373 failed, spg 39 inconsistent
# Idx: 374 failed, spg 39 inconsistent
# Idx: 376 failed, spg 39 inconsistent
# Idx: 377 failed, spg 39 inconsistent
# Idx: 379 failed, spg 39 inconsistent
# Idx: 380 failed, spg 39 inconsistent
# Idx: 381 failed, spg 39 inconsistent
# Idx: 382 failed, spg 39 inconsistent
# Idx: 384 failed, spg 39 inconsistent
# Idx: 385 failed, spg 39 inconsistent
# Idx: 387 failed, spg 39 inconsistent
# Idx: 388 failed, spg 39 inconsistent
# Idx: 389 failed, spg 39 inconsistent
# Idx: 390 failed, spg 39 inconsistent
# Idx: 391 failed, spg 39 inconsistent
# Idx: 392 failed, spg 39 inconsistent
# Idx: 394 failed, spg 39 inconsistent
# Idx: 395 failed, spg 39 inconsistent
# Idx: 396 failed, spg 39 inconsistent
# Idx: 397 failed, spg 39 inconsistent
# Idx: 398 failed, spg 39 inconsistent
# Idx: 399 failed, spg 39 inconsistent
# Idx: 400 failed, spg 39 inconsistent
# Idx: 401 failed, spg 39 inconsistent
# Idx: 404 failed, spg 39 inconsistent
# Idx: 406 failed, spg 39 inconsistent
# Idx: 409 failed, spg 39 inconsistent
# Idx: 410 failed, spg 39 inconsistent
# Idx: 411 failed, spg 39 inconsistent
# Idx: 412 failed, spg 39 inconsistent
# Idx: 413 failed, spg 39 inconsistent
# Idx: 414 failed, spg 39 inconsistent
# Idx: 415 failed, spg 39 inconsistent
# Idx: 416 failed, spg 39 inconsistent
# Idx: 417 failed, spg 39 inconsistent
# Idx: 418 failed, spg 39 inconsistent
# Idx: 419 failed, spg 39 inconsistent
# Idx: 420 failed, spg 39 inconsistent
# Idx: 422 failed, spg 39 inconsistent
# Idx: 423 failed, spg 39 inconsistent
# Idx: 424 failed, spg 39 inconsistent
# Idx: 425 failed, spg 39 inconsistent
# Idx: 426 failed, spg 39 inconsistent
# Idx: 427 failed, spg 39 inconsistent
# Idx: 429 failed, spg 39 inconsistent
# Idx: 430 failed, spg 39 inconsistent
# Idx: 434 failed, spg 39 inconsistent
# Idx: 435 failed, spg 39 inconsistent
# Idx: 438 failed, spg 39 inconsistent
# Idx: 440 failed, spg 39 inconsistent
# Idx: 441 failed, spg 39 inconsistent
# Idx: 442 failed, spg 39 inconsistent
# Idx: 444 failed, spg 39 inconsistent
# Idx: 445 failed, spg 39 inconsistent
# Idx: 447 failed, spg 39 inconsistent
# Idx: 449 failed, spg 39 inconsistent
# Idx: 452 failed, spg 39 inconsistent
# Idx: 455 failed, spg 39 inconsistent
# Idx: 457 failed, spg 39 inconsistent
# Idx: 458 failed, spg 39 inconsistent
# Idx: 459 failed, spg 39 inconsistent
# Idx: 461 failed, spg 39 inconsistent
# Idx: 462 failed, spg 39 inconsistent
# Idx: 463 failed, spg 39 inconsistent
# Idx: 466 failed, spg 39 inconsistent
# Idx: 468 failed, spg 39 inconsistent
# Idx: 469 failed, spg 39 inconsistent
# Idx: 470 failed, spg 39 inconsistent
# Idx: 473 failed, spg 39 inconsistent
# Idx: 474 failed, spg 39 inconsistent
# Idx: 476 failed, spg 39 inconsistent
# Idx: 479 failed, spg 39 inconsistent
# Idx: 480 failed, spg 39 inconsistent
# Idx: 481 failed, spg 39 inconsistent
# Idx: 482 failed, spg 39 inconsistent
# Idx: 483 failed, spg 39 inconsistent
# Idx: 484 failed, spg 39 inconsistent
# Idx: 485 failed, spg 39 inconsistent
# Idx: 486 failed, spg 39 inconsistent
# Idx: 489 failed, spg 39 inconsistent
# Idx: 491 failed, spg 39 inconsistent
# Idx: 492 failed, spg 39 inconsistent
# Idx: 493 failed, spg 39 inconsistent
# Idx: 494 failed, spg 39 inconsistent
# Idx: 502 failed, spg 39 inconsistent
# Idx: 503 failed, spg 39 inconsistent
# Idx: 504 failed, spg 39 inconsistent
# Idx: 505 failed, spg 39 inconsistent
# Idx: 507 failed, spg 39 inconsistent
# Idx: 508 failed, spg 39 inconsistent
# Idx: 510 failed, spg 39 inconsistent
# Idx: 514 failed, spg 39 inconsistent
# Idx: 515 failed, spg 39 inconsistent
# Idx: 517 failed, spg 39 inconsistent
# Idx: 518 failed, spg 39 inconsistent
# Idx: 519 failed, spg 39 inconsistent
# Idx: 520 failed, spg 39 inconsistent
# Idx: 521 failed, spg 39 inconsistent
# Idx: 523 failed, spg 39 inconsistent
# Idx: 525 failed, spg 39 inconsistent
# Idx: 526 failed, spg 39 inconsistent
# Idx: 527 failed, spg 39 inconsistent
# Idx: 528 failed, spg 39 inconsistent
# Idx: 531 failed, spg 39 inconsistent
# Idx: 532 failed, spg 39 inconsistent
# Idx: 533 failed, spg 39 inconsistent
# Idx: 534 failed, spg 39 inconsistent
# Idx: 537 failed, spg 39 inconsistent
# Idx: 538 failed, spg 39 inconsistent
# Idx: 539 failed, spg 39 inconsistent
# Idx: 540 failed, spg 39 inconsistent
# Idx: 542 failed, spg 39 inconsistent
# Idx: 545 failed, spg 39 inconsistent
# Idx: 548 failed, spg 39 inconsistent
# Idx: 549 failed, spg 39 inconsistent
# Idx: 551 failed, spg 39 inconsistent
# Idx: 552 failed, spg 39 inconsistent
# Idx: 553 failed, spg 39 inconsistent
# Idx: 554 failed, spg 39 inconsistent
# Idx: 555 failed, spg 39 inconsistent
# Idx: 556 failed, spg 39 inconsistent
# Idx: 558 failed, spg 39 inconsistent
# Idx: 560 failed, spg 39 inconsistent
# Idx: 562 failed, spg 39 inconsistent
# Idx: 563 failed, spg 39 inconsistent
# Idx: 564 failed, spg 39 inconsistent
# Idx: 566 failed, spg 39 inconsistent
# Idx: 567 failed, spg 39 inconsistent
# Idx: 568 failed, spg 39 inconsistent
# Idx: 569 failed, spg 39 inconsistent
# Idx: 570 failed, spg 39 inconsistent
# Idx: 571 failed, spg 39 inconsistent
# Idx: 573 failed, spg 39 inconsistent
# Idx: 576 failed, spg 39 inconsistent
# Idx: 577 failed, spg 39 inconsistent
# Idx: 578 failed, spg 39 inconsistent
# Idx: 579 failed, spg 39 inconsistent
# Idx: 580 failed, spg 39 inconsistent
# Idx: 581 failed, spg 39 inconsistent
# Idx: 582 failed, spg 39 inconsistent
# Idx: 584 failed, spg 39 inconsistent
# Idx: 585 failed, spg 39 inconsistent
# Idx: 587 failed, spg 39 inconsistent
# Idx: 589 failed, spg 39 inconsistent
# Idx: 591 failed, spg 39 inconsistent
# Idx: 592 failed, spg 39 inconsistent
# Idx: 594 failed, spg 39 inconsistent
# Idx: 597 failed, spg 39 inconsistent
# Idx: 599 failed, spg 39 inconsistent
# Idx: 600 failed, spg 39 inconsistent
# Idx: 602 failed, spg 39 inconsistent
# Idx: 603 failed, spg 39 inconsistent
# Idx: 604 failed, spg 39 inconsistent
# Idx: 607 failed, spg 39 inconsistent
# Idx: 609 failed, spg 39 inconsistent
# Idx: 611 failed, spg 39 inconsistent
# Idx: 614 failed, spg 39 inconsistent
# Idx: 615 failed, spg 39 inconsistent
# Idx: 617 failed, spg 39
# Idx: 617 failed, spg 39 inconsistent
# Idx: 618 failed, spg 39 inconsistent
# Idx: 619 failed, spg 39 inconsistent
# Idx: 620 failed, spg 39 inconsistent
# Idx: 622 failed, spg 39 inconsistent
# Idx: 623 failed, spg 39 inconsistent
# Idx: 624 failed, spg 39 inconsistent
# Idx: 625 failed, spg 39 inconsistent
# Idx: 626 failed, spg 39 inconsistent
# Idx: 627 failed, spg 39 inconsistent
# Idx: 629 failed, spg 39 inconsistent
# Idx: 630 failed, spg 39 inconsistent
# Idx: 631 failed, spg 39 inconsistent
# Idx: 633 failed, spg 39 inconsistent
# Idx: 634 failed, spg 39 inconsistent
# Idx: 635 failed, spg 39 inconsistent
# Idx: 637 failed, spg 39 inconsistent
# Idx: 638 failed, spg 39 inconsistent
# Idx: 641 failed, spg 39 inconsistent
# Idx: 642 failed, spg 39 inconsistent
# Idx: 643 failed, spg 39 inconsistent
# Idx: 645 failed, spg 39 inconsistent
# Idx: 646 failed, spg 39 inconsistent
# Idx: 648 failed, spg 39 inconsistent
# Idx: 649 failed, spg 39 inconsistent
# Idx: 653 failed, spg 39 inconsistent
# Idx: 654 failed, spg 39 inconsistent
# Idx: 655 failed, spg 39 inconsistent
# Idx: 656 failed, spg 39 inconsistent
# Idx: 657 failed, spg 39 inconsistent
# Idx: 658 failed, spg 39 inconsistent
# Idx: 659 failed, spg 39 inconsistent
# Idx: 662 failed, spg 39 inconsistent
# Idx: 663 failed, spg 39 inconsistent
# Idx: 664 failed, spg 39 inconsistent
# Idx: 665 failed, spg 39 inconsistent
# Idx: 666 failed, spg 39 inconsistent
# Idx: 667 failed, spg 39 inconsistent
# Idx: 668 failed, spg 39 inconsistent
# Idx: 670 failed, spg 39 inconsistent
# Idx: 671 failed, spg 39 inconsistent
# Idx: 673 failed, spg 39 inconsistent
# Idx: 674 failed, spg 39 inconsistent
# Idx: 675 failed, spg 39 inconsistent
# Idx: 677 failed, spg 39 inconsistent
# Idx: 678 failed, spg 39 inconsistent
# Idx: 679 failed, spg 39 inconsistent
# Idx: 683 failed, spg 39 inconsistent
# Idx: 684 failed, spg 39 inconsistent
# Idx: 685 failed, spg 39 inconsistent
# Idx: 686 failed, spg 39 inconsistent
# Idx: 687 failed, spg 39 inconsistent
# Idx: 689 failed, spg 39 inconsistent
# Idx: 690 failed, spg 39 inconsistent
# Idx: 691 failed, spg 39 inconsistent
# Idx: 692 failed, spg 39 inconsistent
# Idx: 694 failed, spg 39 inconsistent
# Idx: 695 failed, spg 39 inconsistent
# Idx: 696 failed, spg 39 inconsistent
# Idx: 697 failed, spg 39 inconsistent
# Idx: 698 failed, spg 39 inconsistent
# Idx: 699 failed, spg 39 inconsistent
# Idx: 700 failed, spg 39 inconsistent
# Idx: 702 failed, spg 39 inconsistent
# Idx: 703 failed, spg 39 inconsistent
# Idx: 704 failed, spg 39 inconsistent
# Idx: 706 failed, spg 39 inconsistent
# Idx: 707 failed, spg 39 inconsistent
# Idx: 708 failed, spg 39 inconsistent
# Idx: 710 failed, spg 39 inconsistent
# Idx: 715 failed, spg 39 inconsistent
# Idx: 717 failed, spg 39 inconsistent
# Idx: 718 failed, spg 39 inconsistent
# Idx: 720 failed, spg 39 inconsistent
# Idx: 721 failed, spg 39 inconsistent
# Idx: 722 failed, spg 39 inconsistent
# Idx: 723 failed, spg 39 inconsistent
# Idx: 726 failed, spg 39 inconsistent
# Idx: 728 failed, spg 39 inconsistent
# Idx: 729 failed, spg 39 inconsistent
# Idx: 731 failed, spg 39 inconsistent
# Idx: 732 failed, spg 39 inconsistent
# Idx: 733 failed, spg 39 inconsistent
# Idx: 734 failed, spg 39 inconsistent
# Idx: 736 failed, spg 39 inconsistent
# Idx: 738 failed, spg 39 inconsistent
# Idx: 739 failed, spg 39 inconsistent
# Idx: 740 failed, spg 39 inconsistent
# Idx: 742 failed, spg 39 inconsistent
# Idx: 743 failed, spg 39 inconsistent
# Idx: 746 failed, spg 39 inconsistent
# Idx: 747 failed, spg 39 inconsistent
# Idx: 748 failed, spg 39 inconsistent
# Idx: 749 failed, spg 39 inconsistent
# Idx: 751 failed, spg 39 inconsistent
# Idx: 753 failed, spg 39 inconsistent
# Idx: 754 failed, spg 39 inconsistent
# Idx: 757 failed, spg 39 inconsistent
# Idx: 761 failed, spg 39 inconsistent
# Idx: 762 failed, spg 39 inconsistent
# Idx: 763 failed, spg 39 inconsistent
# Idx: 764 failed, spg 39 inconsistent
# Idx: 765 failed, spg 39 inconsistent
# Idx: 766 failed, spg 39 inconsistent
# Idx: 768 failed, spg 39 inconsistent
# Idx: 769 failed, spg 39 inconsistent
# Idx: 771 failed, spg 39 inconsistent
# Idx: 772 failed, spg 39 inconsistent
# Idx: 773 failed, spg 39 inconsistent
# Idx: 774 failed, spg 39 inconsistent
# Idx: 775 failed, spg 39 inconsistent
# Idx: 776 failed, spg 39 inconsistent
# Idx: 777 failed, spg 39 inconsistent
# Idx: 778 failed, spg 39 inconsistent
# Idx: 779 failed, spg 39 inconsistent
# Idx: 780 failed, spg 39 inconsistent
# Idx: 781 failed, spg 39 inconsistent
# Idx: 782 failed, spg 39 inconsistent
# Idx: 783 failed, spg 39 inconsistent
# Idx: 786 failed, spg 39 inconsistent
# Idx: 787 failed, spg 39 inconsistent
# Idx: 788 failed, spg 39 inconsistent
# Idx: 789 failed, spg 39 inconsistent
# Idx: 792 failed, spg 39 inconsistent
# Idx: 794 failed, spg 39 inconsistent
# Idx: 795 failed, spg 39 inconsistent
# Idx: 797 failed, spg 39 inconsistent
# Idx: 798 failed, spg 39 inconsistent
# Idx: 803 failed, spg 39 inconsistent
# Idx: 804 failed, spg 39 inconsistent
# Idx: 805 failed, spg 39 inconsistent
# Idx: 806 failed, spg 39 inconsistent
# Idx: 807 failed, spg 39 inconsistent
# Idx: 808 failed, spg 39 inconsistent
# Idx: 809 failed, spg 39 inconsistent
# Idx: 810 failed, spg 39 inconsistent
# Idx: 811 failed, spg 39 inconsistent
# Idx: 812 failed, spg 39 inconsistent
# Idx: 813 failed, spg 39 inconsistent
# Idx: 815 failed, spg 39 inconsistent
# Idx: 816 failed, spg 39 inconsistent
# Idx: 817 failed, spg 39 inconsistent
# Idx: 818 failed, spg 39 inconsistent
# Idx: 819 failed, spg 39 inconsistent
# Idx: 822 failed, spg 39
# Idx: 823 failed, spg 39 inconsistent
# Idx: 824 failed, spg 39 inconsistent
# Idx: 825 failed, spg 39 inconsistent
# Idx: 827 failed, spg 39 inconsistent
# Idx: 828 failed, spg 39 inconsistent
# Idx: 829 failed, spg 39 inconsistent
# Idx: 830 failed, spg 39 inconsistent
# Idx: 831 failed, spg 39 inconsistent
# Idx: 833 failed, spg 39 inconsistent
# Idx: 836 failed, spg 39 inconsistent
# Idx: 837 failed, spg 39 inconsistent
# Idx: 839 failed, spg 39 inconsistent
# Idx: 840 failed, spg 39
# Idx: 841 failed, spg 39 inconsistent
# Idx: 842 failed, spg 39 inconsistent
# Idx: 844 failed, spg 39 inconsistent
# Idx: 847 failed, spg 39 inconsistent
# Idx: 848 failed, spg 39 inconsistent
# Idx: 850 failed, spg 39 inconsistent
# Idx: 851 failed, spg 39 inconsistent
# Idx: 852 failed, spg 39 inconsistent
# Idx: 853 failed, spg 39 inconsistent
# Idx: 854 failed, spg 39 inconsistent
# Idx: 857 failed, spg 39 inconsistent
# Idx: 858 failed, spg 39 inconsistent
# Idx: 860 failed, spg 39 inconsistent
# Idx: 861 failed, spg 39 inconsistent
# Idx: 863 failed, spg 39 inconsistent
# Idx: 864 failed, spg 39 inconsistent
# Idx: 865 failed, spg 39 inconsistent
# Idx: 869 failed, spg 39 inconsistent
# Idx: 870 failed, spg 39 inconsistent
# Idx: 871 failed, spg 39 inconsistent
# Idx: 873 failed, spg 39 inconsistent
# Idx: 874 failed, spg 39 inconsistent
# Idx: 876 failed, spg 39 inconsistent
# Idx: 878 failed, spg 39 inconsistent
# Idx: 879 failed, spg 39 inconsistent
# Idx: 881 failed, spg 39 inconsistent
# Idx: 882 failed, spg 39 inconsistent
# Idx: 884 failed, spg 39 inconsistent
# Idx: 886 failed, spg 39 inconsistent
# Idx: 887 failed, spg 39 inconsistent
# Idx: 888 failed, spg 39 inconsistent
# Idx: 889 failed, spg 39 inconsistent
# Idx: 891 failed, spg 39 inconsistent
# Idx: 892 failed, spg 39 inconsistent
# Idx: 893 failed, spg 39 inconsistent
# Idx: 894 failed, spg 39 inconsistent
# Idx: 895 failed, spg 39 inconsistent
# Idx: 896 failed, spg 39 inconsistent
# Idx: 898 failed, spg 39 inconsistent
# Idx: 899 failed, spg 39 inconsistent
# Idx: 900 failed, spg 39 inconsistent
# Idx: 901 failed, spg 39 inconsistent
# Idx: 902 failed, spg 39 inconsistent
# Idx: 903 failed, spg 39 inconsistent
# Idx: 904 failed, spg 39 inconsistent
# Idx: 905 failed, spg 39 inconsistent
# Idx: 907 failed, spg 39 inconsistent
# Idx: 909 failed, spg 39 inconsistent
# Idx: 910 failed, spg 39 inconsistent
# Idx: 911 failed, spg 39 inconsistent
# Idx: 912 failed, spg 39 inconsistent
# Idx: 913 failed, spg 39 inconsistent
# Idx: 914 failed, spg 39 inconsistent
# Idx: 916 failed, spg 39 inconsistent
# Idx: 919 failed, spg 39 inconsistent
# Idx: 921 failed, spg 39 inconsistent
# Idx: 923 failed, spg 39 inconsistent
# Idx: 924 failed, spg 39 inconsistent
# Idx: 925 failed, spg 39 inconsistent
# Idx: 927 failed, spg 39 inconsistent
# Idx: 928 failed, spg 39 inconsistent
# Idx: 929 failed, spg 39 inconsistent
# Idx: 930 failed, spg 39 inconsistent
# Idx: 931 failed, spg 39 inconsistent
# Idx: 932 failed, spg 39 inconsistent
# Idx: 935 failed, spg 39 inconsistent
# Idx: 936 failed, spg 39 inconsistent
# Idx: 938 failed, spg 39 inconsistent
# Idx: 939 failed, spg 39 inconsistent
# Idx: 940 failed, spg 39 inconsistent
# Idx: 941 failed, spg 39 inconsistent
# Idx: 943 failed, spg 39 inconsistent
# Idx: 944 failed, spg 39 inconsistent
# Idx: 946 failed, spg 39 inconsistent
# Idx: 948 failed, spg 39 inconsistent
# Idx: 949 failed, spg 39 inconsistent
# Idx: 951 failed, spg 39 inconsistent
# Idx: 952 failed, spg 39 inconsistent
# Idx: 953 failed, spg 39 inconsistent
# Idx: 956 failed, spg 39 inconsistent
# Idx: 957 failed, spg 39 inconsistent
# Idx: 961 failed, spg 39 inconsistent
# Idx: 962 failed, spg 39 inconsistent
# Idx: 965 failed, spg 39
# Idx: 965 failed, spg 39 inconsistent
# Idx: 968 failed, spg 39 inconsistent
# Idx: 970 failed, spg 39 inconsistent
# Idx: 975 failed, spg 39 inconsistent
# Idx: 976 failed, spg 39 inconsistent
# Idx: 977 failed, spg 39 inconsistent
# Idx: 978 failed, spg 39 inconsistent
# Idx: 979 failed, spg 39 inconsistent
# Idx: 980 failed, spg 39 inconsistent
# Idx: 981 failed, spg 39 inconsistent
# Idx: 982 failed, spg 39 inconsistent
# Idx: 983 failed, spg 39 inconsistent
# Idx: 984 failed, spg 39 inconsistent
# Idx: 985 failed, spg 39 inconsistent
# Idx: 986 failed, spg 39 inconsistent
# Idx: 987 failed, spg 39 inconsistent
# Idx: 988 failed, spg 39 inconsistent
# Idx: 989 failed, spg 39 inconsistent
# Idx: 990 failed, spg 39 inconsistent
# Idx: 992 failed, spg 39 inconsistent
# Idx: 994 failed, spg 39 inconsistent
# Idx: 995 failed, spg 39 inconsistent
# Idx: 996 failed, spg 39 inconsistent
# Idx: 997 failed, spg 39 inconsistent
# Idx: 998 failed, spg 39 inconsistent
# Idx: 999 failed, spg 39 inconsistent
# Len of success:  1000
# Len of failed:  0
# Len of error:  0
# Len of consistency:  326

# %%
inconsistency_data[996]
# Out:
# {'data': ChemGraph(pos=[4, 3], anchors=[4], anchors_len=4, wyckoff_ops=[8, 4, 4], wyckoff_ops_pinv=[8, 3, 3], wyckoff_bat=[8], wyckoff_bat_len=8, space_groups=39, num_atoms=4, conv_to_prim=[1, 3, 3], prim_to_conv=[1, 3, 3], species=[4], uniques=[4], uniques_len=4, num_nodes=4, atomic_numbers=[4], cell=[1, 3, 3]),
#  'coords': tensor([[0.8602, 0.3602, 0.1984],
#          [0.3602, 0.8602, 0.8016],
#          [0.4472, 0.9472, 0.1747],
#          [0.9472, 0.4472, 0.8253]]),
#  'coords2': tensor([[0.3602, 0.8602, 0.1984],
#          [0.8602, 0.3602, 0.8016],
#          [0.4472, 0.9472, 0.1747],
#          [0.9472, 0.4472, 0.8253]]),
#  'lattice': tensor([[[ 3.9991, -6.1928,  0.0000],
#           [ 3.9991,  6.1928,  0.0000],
#           [ 0.0000,  0.0000,  8.4035]]]),
#  'lattice2': tensor([[[ 3.9991, -6.1928,  0.0000],
#           [ 3.9991,  6.1928,  0.0000],
#           [ 0.0000,  0.0000,  8.4035]]]),
#  'pos_frac_proj': tensor([[0.1984, 0.2500, 0.1102],
#          [0.8016, 0.7500, 0.1102],
#          [0.1984, 0.7500, 0.6102],
#          [0.8016, 0.2500, 0.6102],
#          [0.1747, 0.2500, 0.6972],
#          [0.8253, 0.7500, 0.6972],
#          [0.1747, 0.7500, 0.1972],
#          [0.8253, 0.2500, 0.1972]]),
#  'pos_frac_proj2': tensor([[0.1984, 0.2500, 0.6102],
#          [0.8016, 0.7500, 0.6102],
#          [0.1984, 0.7500, 0.1102],
#          [0.8016, 0.2500, 0.1102],
#          [0.1747, 0.2500, 0.6972],
#          [0.8253, 0.7500, 0.6972],
#          [0.1747, 0.7500, 0.1972],
#          [0.8253, 0.2500, 0.1972]]),
#  'conv_lat_proj': tensor([[[ 8.4035,  0.0000,  0.0000],
#           [ 0.0000, 12.3855,  0.0000],
#           [ 0.0000,  0.0000,  7.9982]]]),
#  'conv_lat_proj2': tensor([[[ 8.4035,  0.0000,  0.0000],
#           [ 0.0000, 12.3855,  0.0000],
#           [ 0.0000,  0.0000,  7.9982]]])}

# %%
res = []
success = []
failed = []
error = []
consistency = []
inconsistency_data = {
}

torch.set_num_threads(24)
for idx, data in tqdm(enumerate(dataset)):
    data_batch = collate([data])
    _success = False
    for i in range(3):
        if not _success:
            coords, lattice, pos_frac_proj, conv_lat_proj = _project_to_space_group(data_batch)
            structure = Structure(lattice=lattice, coords=coords, species=data_batch.species)
            try:
                spga = SpacegroupAnalyzer(structure)
            except:
                print(f"Idx: {idx} failed, spg {data.space_groups}")
                continue
            _success = True
    if not _success:
        error.append(idx)
        failed.append(idx)
        continue
    
    coords2, lattice2, pos_frac_proj2, conv_lat_proj2 = _project_to_space_group(data_batch, coords, lattice)
    coords2, lattice2, pos_frac_proj2, conv_lat_proj2 = _project_to_space_group(data_batch, coords2, lattice2)
    if torch.allclose(coords, coords2, atol=1e-3):
        consistency.append(idx)
    else:
        print(f"Idx: {idx} failed, spg {data.space_groups} inconsistent")    
        inconsistency_data[idx]={
            "data": data,
            "coords": coords,
            "coords2": coords2,
            "lattice": lattice,
            "lattice2": lattice2,
            "pos_frac_proj": pos_frac_proj,
            "pos_frac_proj2": pos_frac_proj2,
            "conv_lat_proj": conv_lat_proj,
            "conv_lat_proj2": conv_lat_proj2,
        }
    sgn = spga.get_space_group_number()
    res.append(sgn)
    if sgn == data.space_groups.item():
        success.append(idx)
    else:
        failed.append(idx)
        print(f"Idx: {idx} failed, spg {data.space_groups} != {sgn}")
print("Len of success: ", len(success))
print("Len of failed: ", len(failed))
print("Len of error: ", len(error))
print("Len of consistency: ", len(consistency))
# Out:
# 0it [00:00, ?it/s]
# Idx: 14 failed, spg 119 inconsistent
# Idx: 23 failed, spg 204 inconsistent
# Idx: 40 failed, spg 107 inconsistent
# Idx: 43 failed, spg 139 inconsistent
# Idx: 75 failed, spg 82 inconsistent
# Idx: 76 failed, spg 71 inconsistent
# Idx: 82 failed, spg 155 inconsistent
# Idx: 93 failed, spg 12 inconsistent
# Idx: 101 failed, spg 74 inconsistent
# Idx: 128 failed, spg 139 inconsistent
# Idx: 131 failed, spg 12 inconsistent
# Idx: 139 failed, spg 44 inconsistent
# Idx: 152 failed, spg 227 inconsistent
# Idx: 165 failed, spg 74 inconsistent
# Idx: 170 failed, spg 139 inconsistent
# Idx: 192 failed, spg 71 inconsistent
# Idx: 259 failed, spg 12 inconsistent
# Idx: 281 failed, spg 44 inconsistent
# Idx: 310 failed, spg 44 inconsistent
# Idx: 366 failed, spg 44 inconsistent
# Idx: 389 failed, spg 74 inconsistent
# Idx: 411 failed, spg 166 inconsistent
# Idx: 413 failed, spg 44 inconsistent
# Idx: 416 failed, spg 72 inconsistent
# Idx: 419 failed, spg 71 inconsistent
# Idx: 428 failed, spg 227 inconsistent
# Idx: 438 failed, spg 141 inconsistent
# Idx: 448 failed, spg 139 inconsistent
# Idx: 496 failed, spg 107 inconsistent
# Idx: 521 failed, spg 71 inconsistent
# Idx: 531 failed, spg 74 inconsistent
# Idx: 537 failed, spg 72 inconsistent
# Idx: 553 failed, spg 88 inconsistent
# Idx: 554 failed, spg 64 inconsistent
# Idx: 567 failed, spg 167 inconsistent
# Idx: 572 failed, spg 65 inconsistent
# Idx: 580 failed, spg 74 inconsistent
# Idx: 615 failed, spg 64 inconsistent
# Idx: 616 failed, spg 44 inconsistent
# Idx: 618 failed, spg 119 inconsistent
# Idx: 645 failed, spg 71 inconsistent
# Idx: 663 failed, spg 71 inconsistent
# Idx: 678 failed, spg 72 inconsistent
# Idx: 684 failed, spg 71 inconsistent
# Idx: 702 failed, spg 65 inconsistent
# Idx: 743 failed, spg 220 inconsistent
# Idx: 753 failed, spg 88 inconsistent
# Idx: 779 failed, spg 187
# Idx: 794 failed, spg 44 inconsistent
# Idx: 810 failed, spg 194
# Idx: 818 failed, spg 44 inconsistent
# Idx: 824 failed, spg 87 inconsistent
# Idx: 832 failed, spg 64 inconsistent
# Idx: 851 failed, spg 166 inconsistent
# Idx: 857 failed, spg 44 inconsistent
# Idx: 866 failed, spg 71 inconsistent
# Idx: 867 failed, spg 15 inconsistent
# Idx: 886 failed, spg 71 inconsistent
# Idx: 910 failed, spg 227 inconsistent
# Idx: 916 failed, spg 166 inconsistent
# Idx: 947 failed, spg 87 inconsistent
# Idx: 951 failed, spg 74 inconsistent
# Idx: 964 failed, spg 71 inconsistent
# Idx: 972 failed, spg 166 inconsistent
# Len of success:  1000
# Len of failed:  0
# Len of error:  0
# Len of consistency:  938

# %%
inconsistency_data[964]
# Out:
# {'data': ChemGraph(pos=[13, 3], anchors=[13], anchors_len=13, wyckoff_ops=[26, 4, 4], wyckoff_ops_pinv=[26, 3, 3], wyckoff_bat=[26], wyckoff_bat_len=26, space_groups=71, num_atoms=13, conv_to_prim=[1, 3, 3], prim_to_conv=[1, 3, 3], species=[13], uniques=[13], uniques_len=13, num_nodes=13, atomic_numbers=[13], cell=[1, 3, 3]),
#  'coords': tensor([[0.0000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [1.0000, 0.0000, 0.5000],
#          [1.0000, 0.5000, 0.0000],
#          [0.5000, 0.0000, 0.0000],
#          [0.9351, 0.4351, 0.5000],
#          [0.0649, 0.5649, 0.5000],
#          [0.1055, 0.0000, 0.1055],
#          [0.8945, 0.0000, 0.8945],
#          [0.3456, 0.3456, 0.0000],
#          [0.6544, 0.6544, 0.0000],
#          [0.0892, 0.5000, 0.5892],
#          [0.9108, 0.5000, 0.4108]]),
#  'coords2': tensor([[0.0000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.5000],
#          [0.0000, 0.5000, 0.0000],
#          [0.5000, 0.0000, 0.0000],
#          [0.4351, 0.9351, 0.5000],
#          [0.5649, 0.0649, 0.5000],
#          [0.1055, 0.0000, 0.1055],
#          [0.8945, 0.0000, 0.8945],
#          [0.3456, 0.3456, 0.0000],
#          [0.6544, 0.6544, 0.0000],
#          [0.5892, 0.5000, 0.0892],
#          [0.4108, 0.5000, 0.9108]]),
#  'lattice': tensor([[[-4.5447,  3.2987,  2.7787],
#           [ 4.5447, -3.2987,  2.7787],
#           [ 4.5447,  3.2987, -2.7787]]]),
#  'lattice2': tensor([[[-4.5447,  3.2987,  2.7787],
#           [ 4.5447, -3.2987,  2.7787],
#           [ 4.5447,  3.2987, -2.7787]]]),
#  'pos_frac_proj': tensor([[0.0000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.2500, 0.2500, 0.2500],
#          [0.7500, 0.7500, 0.2500],
#          [0.7500, 0.2500, 0.7500],
#          [0.2500, 0.7500, 0.7500],
#          [0.7500, 0.7500, 0.7500],
#          [0.2500, 0.2500, 0.7500],
#          [0.2500, 0.7500, 0.2500],
#          [0.7500, 0.2500, 0.2500],
#          [0.5000, 0.0000, 0.9351],
#          [0.5000, 0.0000, 0.0649],
#          [0.0000, 0.5000, 0.4351],
#          [0.0000, 0.5000, 0.5649],
#          [0.0000, 0.1055, 0.0000],
#          [0.0000, 0.8945, 0.0000],
#          [0.5000, 0.6055, 0.5000],
#          [0.5000, 0.3945, 0.5000],
#          [0.0000, 0.0000, 0.3456],
#          [0.0000, 0.0000, 0.6544],
#          [0.5000, 0.5000, 0.8456],
#          [0.5000, 0.5000, 0.1544],
#          [0.0000, 0.5892, 0.5000],
#          [0.0000, 0.4108, 0.5000],
#          [0.5000, 0.0892, 0.0000],
#          [0.5000, 0.9108, 0.0000]]),
#  'pos_frac_proj2': tensor([[0.0000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.2500, 0.2500, 0.2500],
#          [0.7500, 0.7500, 0.2500],
#          [0.7500, 0.2500, 0.7500],
#          [0.2500, 0.7500, 0.7500],
#          [0.7500, 0.7500, 0.7500],
#          [0.2500, 0.2500, 0.7500],
#          [0.2500, 0.7500, 0.2500],
#          [0.7500, 0.2500, 0.2500],
#          [0.5000, 0.0000, 0.4351],
#          [0.5000, 0.0000, 0.5649],
#          [0.0000, 0.5000, 0.9351],
#          [0.0000, 0.5000, 0.0649],
#          [0.0000, 0.1055, 0.0000],
#          [0.0000, 0.8945, 0.0000],
#          [0.5000, 0.6055, 0.5000],
#          [0.5000, 0.3945, 0.5000],
#          [0.0000, 0.0000, 0.3456],
#          [0.0000, 0.0000, 0.6544],
#          [0.5000, 0.5000, 0.8456],
#          [0.5000, 0.5000, 0.1544],
#          [0.0000, 0.0892, 0.5000],
#          [0.0000, 0.9108, 0.5000],
#          [0.5000, 0.5892, 0.0000],
#          [0.5000, 0.4108, 0.0000]]),
#  'conv_lat_proj': tensor([[[9.0893, 0.0000, 0.0000],
#           [0.0000, 6.5975, 0.0000],
#           [0.0000, 0.0000, 5.5574]]]),
#  'conv_lat_proj2': tensor([[[9.0893, 0.0000, 0.0000],
#           [0.0000, 6.5975, 0.0000],
#           [0.0000, 0.0000, 5.5574]]])}

# %%
inconsistency_data[964]["data"].conv_to_prim
# Out:
# tensor([[[-0.5000,  0.5000,  0.5000],
#          [ 0.5000, -0.5000,  0.5000],
#          [ 0.5000,  0.5000, -0.5000]]])

# %%
inconsistency_data[964]['pos_frac_proj'] - inconsistency_data[964]['pos_frac_proj2']
# Out:
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00, -5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00, -5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  5.0000e-01],
#         [ 0.0000e+00, -7.4506e-09,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00, -5.9605e-08],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  5.9605e-08],
#         [ 0.0000e+00,  5.0000e-01,  0.0000e+00],
#         [ 0.0000e+00, -5.0000e-01,  0.0000e+00],
#         [ 0.0000e+00, -5.0000e-01,  0.0000e+00],
#         [ 0.0000e+00,  5.0000e-01,  0.0000e+00]])

# %%
_project_to_space_group(collate(inconsistency_data[988]['data']), inconsistency_data[988]['coords2'], inconsistency_data[988]['lattice2'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[329], line 1
# ----> 1 _project_to_space_group(collate(inconsistency_data[988]['data']), inconsistency_data[988]['coords2'], inconsistency_data[988]['lattice2'])
#
# KeyError: 988

# %%
def test(data):
    return _project_to_space_group(collate(data['data']), data['coords2'], data['lattice2'])

# %%
test(inconsistency_data[991])
# Out:
# (tensor([[0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000]]),
#  tensor([[[ 5.6984, -3.4987,  0.0000],
#           [ 5.6984,  3.4987,  0.0000],
#           [ 0.0000,  0.0000,  7.5526]]]),
#  tensor([[0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000],
#          [0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000],
#          [0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000]]),
#  tensor([[[ 7.5526,  0.0000,  0.0000],
#           [ 0.0000, 11.3969,  0.0000],
#           [ 0.0000,  0.0000,  6.9974]]]))

# %%
tt = torch.zeros(4,3)
tt[0][0] = 0.5
tt[0][1] = 0.5
_project_to_space_group(collate(inconsistency_data[997]['data']), inconsistency_data[997]['coords'] + tt, inconsistency_data[997]['lattice2'])
# Out:
# (tensor([[0.0413, 0.9587, 0.0000],
#          [0.4285, 0.5715, 0.5000],
#          [0.9914, 0.1041, 0.5000],
#          [0.8959, 0.0086, 0.5000]]),
#  tensor([[[ 4.9253, -2.9612,  0.0000],
#           [ 4.9253,  2.9612,  0.0000],
#           [ 0.0000,  0.0000,  8.0759]]]),
#  tensor([[0.0000, 0.0000, 0.9587],
#          [0.0000, 0.5000, 0.4587],
#          [0.5000, 0.0000, 0.5715],
#          [0.5000, 0.5000, 0.0715],
#          [0.5000, 0.5477, 0.5563],
#          [0.5000, 0.4523, 0.5563],
#          [0.5000, 0.0477, 0.0563],
#          [0.5000, 0.9523, 0.0563]]),
#  tensor([[[8.0759, 0.0000, 0.0000],
#           [0.0000, 9.8507, 0.0000],
#           [0.0000, 0.0000, 5.9224]]]))

# %%
inconsistency_data[997]['coords'] + tt
# Out:
# tensor([[0.2913, 0.2087, 0.0000],
#         [0.9285, 0.0715, 0.5000],
#         [0.9914, 0.1041, 0.5000],
#         [0.8959, 0.0086, 0.5000]])

# %%
inconsistency_data[991]
# Out:
# {'data': ChemGraph(pos=[7, 3], anchors=[7], anchors_len=7, wyckoff_ops=[14, 4, 4], wyckoff_ops_pinv=[14, 3, 3], wyckoff_bat=[14], wyckoff_bat_len=14, space_groups=38, num_atoms=7, conv_to_prim=[1, 3, 3], prim_to_conv=[1, 3, 3], species=[7], uniques=[7], uniques_len=7, num_nodes=7, atomic_numbers=[7], cell=[1, 3, 3]),
#  'coords': tensor([[0.3364, 0.3364, 0.5000],
#          [0.0529, 0.0529, 0.0000],
#          [0.0825, 0.0825, 0.5000],
#          [0.2610, 0.2610, 0.5000],
#          [0.3855, 0.3855, 0.0000],
#          [0.0591, 0.0591, 0.5000],
#          [0.4593, 0.4593, 0.0000]]),
#  'coords2': tensor([[0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000]]),
#  'lattice': tensor([[[ 5.6984, -3.4987,  0.0000],
#           [ 5.6984,  3.4987,  0.0000],
#           [ 0.0000,  0.0000,  7.5526]]]),
#  'lattice2': tensor([[[ 5.6984, -3.4987,  0.0000],
#           [ 5.6984,  3.4987,  0.0000],
#           [ 0.0000,  0.0000,  7.5526]]]),
#  'pos_frac_proj': tensor([[0.5000, 0.0000, 0.3364],
#          [0.5000, 0.5000, 0.8364],
#          [0.0000, 0.0000, 0.0529],
#          [0.0000, 0.5000, 0.5529],
#          [0.5000, 0.0000, 0.0825],
#          [0.5000, 0.5000, 0.5825],
#          [0.5000, 0.0000, 0.2610],
#          [0.5000, 0.5000, 0.7610],
#          [0.0000, 0.0000, 0.3855],
#          [0.0000, 0.5000, 0.8855],
#          [0.5000, 0.0000, 0.0591],
#          [0.5000, 0.5000, 0.5591],
#          [0.0000, 0.0000, 0.4593],
#          [0.0000, 0.5000, 0.9593]]),
#  'pos_frac_proj2': tensor([[0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000],
#          [0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000],
#          [0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000]]),
#  'conv_lat_proj': tensor([[[ 7.5526,  0.0000,  0.0000],
#           [ 0.0000,  6.9974,  0.0000],
#           [ 0.0000,  0.0000, 11.3969]]]),
#  'conv_lat_proj2': tensor([[[ 7.5526,  0.0000,  0.0000],
#           [ 0.0000, 11.3969,  0.0000],
#           [ 0.0000,  0.0000,  6.9974]]])}

# %%
inconsistency_data[991]['data'].wyckoff_ops
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 1.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 1.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 1.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 1.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 1.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 1.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 1.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.5000],
#          [0.0000, 0.0000, 1.0000, 0.5000],
#          [0.0000, 0.0000, 0.0000, 1.0000]]])

# %%
inconsistency_data[999]['data'].wyckoff_bat
# Out:
# tensor([0, 0, 1, 1, 2, 2, 2, 2])

# %%
coords2
# Out:
# tensor([[0.4597, 0.6486, 0.0000],
#         [0.3514, 0.5403, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.6080, 0.2668, 0.0000],
#         [0.7332, 0.3920, 0.0000],
#         [0.0000, 0.0000, 0.5000],
#         [0.6685, 0.1513, 0.5000],
#         [0.8487, 0.3315, 0.5000],
#         [0.0000, 0.0000, 0.0000],
#         [0.9174, 0.2636, 0.0000],
#         [0.7364, 0.0826, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.4904, 0.4511, 0.0000],
#         [0.5489, 0.5096, 0.0000],
#         [0.6182, 0.0268, 0.5000],
#         [0.9732, 0.3818, 0.5000],
#         [0.9021, 0.4930, 0.5000],
#         [0.5070, 0.0979, 0.5000],
#         [0.3404, 0.1641, 0.5000],
#         [0.8359, 0.6596, 0.5000]])

# %%
lattice, lattice2
# Out:
# (tensor([[[ 4.2064, -2.5449,  0.0000],
#           [ 4.2064,  2.5449,  0.0000],
#           [ 0.0000,  0.0000,  5.7486]]]),
#  tensor([[[ 4.2064, -2.5449,  0.0000],
#           [ 4.2064,  2.5449,  0.0000],
#           [ 0.0000,  0.0000,  5.7486]]]))

# %%
coords
# Out:
# tensor([[0.4597, 0.6486, 0.0000],
#         [0.6486, 0.4597, 0.0000],
#         [0.2180, 0.2180, 0.0000],
#         [0.6080, 0.2668, 0.0000],
#         [0.2668, 0.6080, 0.0000],
#         [0.3282, 0.3282, 0.5000],
#         [0.6685, 0.1513, 0.5000],
#         [0.1513, 0.6685, 0.5000],
#         [0.0999, 0.0999, 0.0000],
#         [0.9174, 0.2636, 0.0000],
#         [0.2636, 0.9174, 0.0000],
#         [0.2413, 0.2413, 0.0000],
#         [0.4904, 0.4511, 0.0000],
#         [0.4511, 0.4904, 0.0000],
#         [0.6182, 0.0268, 0.5000],
#         [0.0268, 0.6182, 0.5000],
#         [0.9021, 0.4930, 0.5000],
#         [0.4930, 0.9021, 0.5000],
#         [0.3404, 0.1641, 0.5000],
#         [0.1641, 0.3404, 0.5000]])

# %%
_project_to_space_group(data_batch, coords2, lattice2)
# Out:
# (tensor([[0.4597, 0.6486, 0.0000],
#          [0.3514, 0.5403, 0.0000],
#          [0.0000, 0.0000, 0.0000],
#          [0.6080, 0.2668, 0.0000],
#          [0.7332, 0.3920, 0.0000],
#          [0.0000, 0.0000, 0.5000],
#          [0.6685, 0.1513, 0.5000],
#          [0.8487, 0.3315, 0.5000],
#          [0.0000, 0.0000, 0.0000],
#          [0.9174, 0.2636, 0.0000],
#          [0.7364, 0.0826, 0.0000],
#          [0.0000, 0.0000, 0.0000],
#          [0.4904, 0.4511, 0.0000],
#          [0.5489, 0.5096, 0.0000],
#          [0.6182, 0.0268, 0.5000],
#          [0.9732, 0.3818, 0.5000],
#          [0.9021, 0.4930, 0.5000],
#          [0.5070, 0.0979, 0.5000],
#          [0.3404, 0.1641, 0.5000],
#          [0.8359, 0.6596, 0.5000]]),
#  tensor([[[ 4.2064, -2.5449,  0.0000],
#           [ 4.2064,  2.5449,  0.0000],
#           [ 0.0000,  0.0000,  5.7486]]]),
#  tensor([[0.0000, 0.5541, 0.0945],
#          [0.0000, 0.4459, 0.0945],
#          [0.0000, 0.0541, 0.5945],
#          [0.0000, 0.9459, 0.5945],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000],
#          [0.0000, 0.4374, 0.8294],
#          [0.0000, 0.5626, 0.8294],
#          [0.0000, 0.9374, 0.3294],
#          [0.0000, 0.0626, 0.3294],
#          [0.5000, 0.0000, 0.0000],
#          [0.5000, 0.5000, 0.5000],
#          [0.5000, 0.4099, 0.7414],
#          [0.5000, 0.5901, 0.7414],
#          [0.5000, 0.9099, 0.2414],
#          [0.5000, 0.0901, 0.2414],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000],
#          [0.0000, 0.5905, 0.6731],
#          [0.0000, 0.4095, 0.6731],
#          [0.0000, 0.0905, 0.1731],
#          [0.0000, 0.9095, 0.1731],
#          [0.0000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000],
#          [0.0000, 0.4708, 0.9804],
#          [0.0000, 0.5292, 0.9804],
#          [0.0000, 0.9708, 0.4804],
#          [0.0000, 0.0292, 0.4804],
#          [0.5000, 0.3225, 0.7043],
#          [0.5000, 0.6775, 0.7043],
#          [0.5000, 0.8225, 0.2043],
#          [0.5000, 0.1775, 0.2043],
#          [0.5000, 0.6976, 0.7955],
#          [0.5000, 0.3024, 0.7955],
#          [0.5000, 0.1976, 0.2955],
#          [0.5000, 0.8024, 0.2955],
#          [0.5000, 0.2522, 0.9119],
#          [0.5000, 0.7478, 0.9119],
#          [0.5000, 0.7522, 0.4119],
#          [0.5000, 0.2478, 0.4119]]),
#  tensor([[[5.7486, 0.0000, 0.0000],
#           [0.0000, 8.4127, 0.0000],
#           [0.0000, 0.0000, 5.0898]]]))

# %%
structure
# Out:
# Structure Summary
# Lattice
#     abc : 8.877142777163153 8.877142777163153 6.539999961853027
#  angles : 90.0 90.0 109.19969093458923
#  volume : 486.7097915451345
#       A : 5.142381191253662 -7.235991954803467 0.0
#       B : 5.142381191253662 7.235991954803467 0.0
#       C : 0.0 0.0 6.539999961853027
#     pbc : True True True
# PeriodicSite: Ca (5.212, 6.928, 0.0) [0.02799, 0.9855, 0.0]
# PeriodicSite: Ca (5.212, -6.928, 0.0) [0.9855, 0.02799, 0.0]
# PeriodicSite: Ca (3.652, 2.156e-07, 0.0) [0.3551, 0.3551, 0.0]
# PeriodicSite: Er (6.521, -3.215, 0.0) [0.8562, 0.4119, 0.0]
# PeriodicSite: Er (6.521, 3.215, 0.0) [0.4119, 0.8562, 0.0]
# PeriodicSite: Sn (0.599, 2.696e-08, 3.27) [0.05824, 0.05824, 0.5]
# PeriodicSite: Sn (5.738, 1.795, 3.27) [0.4339, 0.6819, 0.5]
# PeriodicSite: Sn (5.738, -1.795, 3.27) [0.6819, 0.4339, 0.5]
# PeriodicSite: S (3.647, 2.156e-07, 0.0) [0.3546, 0.3546, 0.0]
# PeriodicSite: S (6.651, -4.768, 0.0) [0.9762, 0.3173, 0.0]
# PeriodicSite: S (6.651, 4.768, 0.0) [0.3173, 0.9762, 0.0]
# PeriodicSite: S (2.221, 1.078e-07, 0.0) [0.2159, 0.2159, 0.0]
# PeriodicSite: S (4.614, 4.051, 0.0) [0.1687, 0.7286, 0.0]
# PeriodicSite: S (4.614, -4.051, 0.0) [0.7286, 0.1687, 0.0]
# PeriodicSite: S (0.2901, 0.3916, 3.27) [0.00115, 0.05526, 0.5]
# PeriodicSite: S (0.2901, -0.3916, 3.27) [0.05526, 0.00115, 0.5]
# PeriodicSite: S (6.788, -4.065, 3.27) [0.9409, 0.3791, 0.5]
# PeriodicSite: S (6.788, 4.065, 3.27) [0.3791, 0.9409, 0.5]
# PeriodicSite: S (6.309, -2.897, 3.27) [0.8136, 0.4133, 0.5]
# PeriodicSite: S (6.309, 2.897, 3.27) [0.4133, 0.8136, 0.5]

# %%
spga.get_refined_structure()
# Out:
# Structure Summary
# Lattice
#     abc : 6.539999961853027 14.471983909606934 10.284762382507324
#  angles : 90.0 90.0 90.0
#  volume : 973.419583090269
#       A : 6.539999961853027 0.0 0.0
#       B : 0.0 14.471983909606934 0.0
#       C : 0.0 0.0 10.284762382507324
#     pbc : True True True
# PeriodicSite: Ca (0.0, 6.928, 5.212) [0.0, 0.4788, 0.5067]
# PeriodicSite: Ca (0.0, 7.543, 5.212) [0.0, 0.5212, 0.5067]
# PeriodicSite: Ca (0.0, 0.0, 3.652) [0.0, 0.0, 0.3551]
# PeriodicSite: Ca (0.0, 14.16, 0.06929) [0.0, 0.9788, 0.006737]
# PeriodicSite: Ca (0.0, 0.3075, 0.06929) [0.0, 0.02125, 0.006737]
# PeriodicSite: Ca (0.0, 7.236, 8.795) [0.0, 0.5, 0.8551]
# PeriodicSite: Er (0.0, 11.26, 6.521) [0.0, 0.7779, 0.6341]
# PeriodicSite: Er (0.0, 3.215, 6.521) [0.0, 0.2221, 0.6341]
# PeriodicSite: Er (0.0, 4.021, 1.379) [0.0, 0.2779, 0.1341]
# PeriodicSite: Er (0.0, 10.45, 1.379) [0.0, 0.7221, 0.1341]
# PeriodicSite: Sn (3.27, 0.0, 0.599) [0.5, 0.0, 0.05824]
# PeriodicSite: Sn (3.27, 1.795, 5.738) [0.5, 0.124, 0.5579]
# PeriodicSite: Sn (3.27, 12.68, 5.738) [0.5, 0.876, 0.5579]
# PeriodicSite: Sn (3.27, 7.236, 5.741) [0.5, 0.5, 0.5582]
# PeriodicSite: Sn (3.27, 9.031, 0.5954) [0.5, 0.624, 0.05789]
# PeriodicSite: Sn (3.27, 5.441, 0.5954) [0.5, 0.376, 0.05789]
# PeriodicSite: S (0.0, 0.0, 3.647) [0.0, 0.0, 0.3546]
# PeriodicSite: S (0.0, 9.704, 6.651) [0.0, 0.6705, 0.6467]
# PeriodicSite: S (0.0, 4.768, 6.651) [0.0, 0.3295, 0.6467]
# PeriodicSite: S (0.0, 0.0, 2.221) [0.0, 0.0, 0.2159]
# PeriodicSite: S (0.0, 4.051, 4.614) [0.0, 0.28, 0.4487]
# PeriodicSite: S (0.0, 10.42, 4.614) [0.0, 0.72, 0.4487]
# PeriodicSite: S (3.27, 0.3916, 0.2901) [0.5, 0.02706, 0.02821]
# PeriodicSite: S (3.27, 14.08, 0.2901) [0.5, 0.9729, 0.02821]
# PeriodicSite: S (3.27, 10.41, 6.788) [0.5, 0.7191, 0.66]
# PeriodicSite: S (3.27, 4.065, 6.788) [0.5, 0.2809, 0.66]
# PeriodicSite: S (3.27, 11.58, 6.309) [0.5, 0.7998, 0.6134]
# PeriodicSite: S (3.27, 2.897, 6.309) [0.5, 0.2002, 0.6134]
# PeriodicSite: S (0.0, 7.236, 8.79) [0.0, 0.5, 0.8546]
# PeriodicSite: S (0.0, 2.468, 1.509) [0.0, 0.1705, 0.1467]
# PeriodicSite: S (0.0, 12.0, 1.509) [0.0, 0.8295, 0.1467]
# PeriodicSite: S (0.0, 7.236, 7.363) [0.0, 0.5, 0.7159]
# PeriodicSite: S (0.0, 11.29, 9.757) [0.0, 0.78, 0.9487]
# PeriodicSite: S (0.0, 3.185, 9.757) [0.0, 0.22, 0.9487]
# PeriodicSite: S (3.27, 7.628, 5.432) [0.5, 0.5271, 0.5282]
# PeriodicSite: S (3.27, 6.844, 5.432) [0.5, 0.4729, 0.5282]
# PeriodicSite: S (3.27, 3.171, 1.645) [0.5, 0.2191, 0.16]
# PeriodicSite: S (3.27, 11.3, 1.645) [0.5, 0.7809, 0.16]
# PeriodicSite: S (3.27, 4.339, 1.167) [0.5, 0.2998, 0.1134]
# PeriodicSite: S (3.27, 10.13, 1.167) [0.5, 0.7002, 0.1134]

# %%
conv = Structure(lattice=conv_lat_proj, coords=pos_frac_proj, species=data_batch.species[data_batch.wyckoff_bat])
SpacegroupAnalyzer(conv).get_space_group_number()
# Out:
# 38

# %%
conv
# Out:
# Structure Summary
# Lattice
#     abc : 6.539999961853027 14.471983909606934 10.284762382507324
#  angles : 90.0 90.0 90.0
#  volume : 973.419583090269
#       A : 6.539999961853027 0.0 0.0
#       B : 0.0 14.471983909606934 0.0
#       C : 0.0 0.0 10.284762382507324
#     pbc : True True True
# PeriodicSite: Ca (0.0, 6.928, 5.212) [0.0, 0.4788, 0.5067]
# PeriodicSite: Ca (0.0, 7.543, 5.212) [0.0, 0.5212, 0.5067]
# PeriodicSite: Ca (0.0, 14.16, 0.06929) [0.0, 0.9788, 0.006737]
# PeriodicSite: Ca (0.0, 0.3075, 0.06929) [0.0, 0.02125, 0.006737]
# PeriodicSite: Ca (0.0, 0.0, 3.652) [0.0, 0.0, 0.3551]
# PeriodicSite: Ca (0.0, 7.236, 8.795) [0.0, 0.5, 0.8551]
# PeriodicSite: Er (0.0, 4.021, 1.379) [0.0, 0.2779, 0.1341]
# PeriodicSite: Er (0.0, 10.45, 1.379) [0.0, 0.7221, 0.1341]
# PeriodicSite: Er (0.0, 11.26, 6.521) [0.0, 0.7779, 0.6341]
# PeriodicSite: Er (0.0, 3.215, 6.521) [0.0, 0.2221, 0.6341]
# PeriodicSite: Sn (3.27, 0.0, 0.599) [0.5, 0.0, 0.05824]
# PeriodicSite: Sn (3.27, 7.236, 5.741) [0.5, 0.5, 0.5582]
# PeriodicSite: Sn (3.27, 9.031, 0.5954) [0.5, 0.624, 0.05789]
# PeriodicSite: Sn (3.27, 5.441, 0.5954) [0.5, 0.376, 0.05789]
# PeriodicSite: Sn (3.27, 1.795, 5.738) [0.5, 0.124, 0.5579]
# PeriodicSite: Sn (3.27, 12.68, 5.738) [0.5, 0.876, 0.5579]
# PeriodicSite: S (0.0, 0.0, 3.647) [0.0, 0.0, 0.3546]
# PeriodicSite: S (0.0, 7.236, 8.79) [0.0, 0.5, 0.8546]
# PeriodicSite: S (0.0, 9.704, 6.651) [0.0, 0.6705, 0.6467]
# PeriodicSite: S (0.0, 4.768, 6.651) [0.0, 0.3295, 0.6467]
# PeriodicSite: S (0.0, 2.468, 1.509) [0.0, 0.1705, 0.1467]
# PeriodicSite: S (0.0, 12.0, 1.509) [0.0, 0.8295, 0.1467]
# PeriodicSite: S (0.0, 0.0, 2.221) [0.0, 0.0, 0.2159]
# PeriodicSite: S (0.0, 7.236, 7.363) [0.0, 0.5, 0.7159]
# PeriodicSite: S (0.0, 4.051, 4.614) [0.0, 0.28, 0.4487]
# PeriodicSite: S (0.0, 10.42, 4.614) [0.0, 0.72, 0.4487]
# PeriodicSite: S (0.0, 11.29, 9.757) [0.0, 0.78, 0.9487]
# PeriodicSite: S (0.0, 3.185, 9.757) [0.0, 0.22, 0.9487]
# PeriodicSite: S (3.27, 0.3916, 0.2901) [0.5, 0.02706, 0.02821]
# PeriodicSite: S (3.27, 14.08, 0.2901) [0.5, 0.9729, 0.02821]
# PeriodicSite: S (3.27, 7.628, 5.432) [0.5, 0.5271, 0.5282]
# PeriodicSite: S (3.27, 6.844, 5.432) [0.5, 0.4729, 0.5282]
# PeriodicSite: S (3.27, 10.41, 6.788) [0.5, 0.7191, 0.66]
# PeriodicSite: S (3.27, 4.065, 6.788) [0.5, 0.2809, 0.66]
# PeriodicSite: S (3.27, 3.171, 1.645) [0.5, 0.2191, 0.16]
# PeriodicSite: S (3.27, 11.3, 1.645) [0.5, 0.7809, 0.16]
# PeriodicSite: S (3.27, 11.58, 6.309) [0.5, 0.7998, 0.6134]
# PeriodicSite: S (3.27, 2.897, 6.309) [0.5, 0.2002, 0.6134]
# PeriodicSite: S (3.27, 4.339, 1.167) [0.5, 0.2998, 0.1134]
# PeriodicSite: S (3.27, 10.13, 1.167) [0.5, 0.7002, 0.1134]

# %%
SpacegroupAnalyzer(conv).get_primitive_standard_structure()
# Out:
# Structure Summary
# Lattice
#     abc : 8.877142777163153 8.877142777163153 6.539999961853027
#  angles : 90.0 90.0 109.19969093458923
#  volume : 486.7097915451345
#       A : 5.142381191253661 -7.235991954803467 -1.281966860120857e-16
#       B : 5.142381191253663 7.235991954803467 7.579567525985208e-16
#       C : 0.0 0.0 6.539999961853027
#     pbc : True True True
# PeriodicSite: Ca (5.212, 6.928, 7.434e-16) [0.02799, 0.9855, 0.0]
# PeriodicSite: Ca (5.212, -6.928, 6.54) [0.9855, 0.02799, 1.0]
# PeriodicSite: Ca (3.652, -8.882e-16, 2.236e-16) [0.3551, 0.3551, 0.0]
# PeriodicSite: Er (6.521, -3.215, 2.025e-16) [0.8562, 0.4119, 0.0]
# PeriodicSite: Er (6.521, 3.215, 6.54) [0.4119, 0.8562, 1.0]
# PeriodicSite: Sn (0.599, 0.0, 3.27) [0.05824, 0.05824, 0.5]
# PeriodicSite: Sn (5.738, 1.795, 3.27) [0.4339, 0.6819, 0.5]
# PeriodicSite: Sn (5.738, -1.795, 3.27) [0.6819, 0.4339, 0.5]
# PeriodicSite: S (3.647, -8.882e-16, 2.233e-16) [0.3546, 0.3546, 2.465e-32]
# PeriodicSite: S (6.651, -4.768, 1.153e-16) [0.9762, 0.3173, 0.0]
# PeriodicSite: S (6.651, 4.768, 6.54) [0.3173, 0.9762, 1.0]
# PeriodicSite: S (2.221, -1.554e-15, 1.36e-16) [0.2159, 0.2159, 2.465e-32]
# PeriodicSite: S (4.614, 4.051, 6.54) [0.1687, 0.7286, 1.0]
# PeriodicSite: S (4.614, -4.051, 3.447e-17) [0.7286, 0.1687, 4.93e-32]
# PeriodicSite: S (0.2901, 0.3916, 3.27) [0.00115, 0.05526, 0.5]
# PeriodicSite: S (0.2901, -0.3916, 3.27) [0.05526, 0.00115, 0.5]
# PeriodicSite: S (6.788, -4.065, 3.27) [0.9409, 0.3791, 0.5]
# PeriodicSite: S (6.788, 4.065, 3.27) [0.3791, 0.9409, 0.5]
# PeriodicSite: S (6.309, -2.897, 3.27) [0.8136, 0.4133, 0.5]
# PeriodicSite: S (6.309, 2.897, 3.27) [0.4133, 0.8136, 0.5]
